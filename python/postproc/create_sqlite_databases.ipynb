# %%
import sqlite3

import os
os.environ["JAVA_HOME"] = "/mnt/extproj/projekte/textmining/jdk/openlogic-openjdk-11.0.22+7-linux-x64"

from collections import defaultdict
from pyspark.sql import SparkSession

from pyspark.sql.functions import *
from pyspark.sql.types import *

from pyspark.sql import Window

from collections import Counter

# %%
dbFile = '/mnt/extproj/projekte/textmining/mx_frontend/cons_evidences.db'

# %%
os.remove(dbFile)

# %%
con =  sqlite3.connect(dbFile)
cur = con.cursor()

# %%
cur.execute("DROP TABLE IF EXISTS mx;")
cur.execute("DROP TABLE IF EXISTS mx_int;")
cur.execute("DROP TABLE IF EXISTS mx_annot;")
cur.execute("DROP TABLE IF EXISTS mx_sent;")
cur.execute("DROP TABLE IF EXISTS mx_dates;")


ct = """CREATE TABLE "mx" (
"index" INTEGER PRIMARY KEY AUTOINCREMENT,
"miRNA_family" TEXT,
"gene_family" TEXT,
"interaction" TEXT,
"organisms" TEXT,
"evidence_documents" TEXT,
"sent_evidences" TEXT,
"evidence_count" INTEGER,
"sent_count" INTEGER,
"is_consensus" INTEGER
)"""
cur.execute(ct)

ct = """CREATE TABLE "mx_int" (
"index" INTEGER PRIMARY KEY AUTOINCREMENT,
"miRNA_family" TEXT,
"gene_family" TEXT,
"interaction" TEXT,
"evidence_documents" TEXT
)"""
cur.execute(ct)

ct = """CREATE TABLE "mx_annot" (
"index" INTEGER PRIMARY KEY AUTOINCREMENT,
"doc_id" TEXT,
"annotation" TEXT,
"concept_id" TEXT,
"concept" TEXT,
"num_occurrences" INTEGER,
"sent_evidences" TEXT
)"""
cur.execute(ct)

ct = """CREATE TABLE "mx_sent" (
"index" INTEGER PRIMARY KEY AUTOINCREMENT,
"doc_id" TEXT,
"sent_id" TEXT,
"sentence" TEXT
)"""
cur.execute(ct)

ct = """CREATE TABLE "mx_dates" (
"index" INTEGER PRIMARY KEY AUTOINCREMENT,
"doc_id" TEXT,
"date" TEXT
)"""
cur.execute(ct)


cur.execute("CREATE INDEX IF NOT EXISTS mx_mirna on mx (miRNA_family);")
cur.execute("CREATE INDEX IF NOT EXISTS mx_gene on mx (gene_family);")
cur.execute("CREATE INDEX IF NOT EXISTS mx_interaction on mx (interaction);")
cur.execute("CREATE INDEX IF NOT EXISTS mx_evs on mx (evidence_documents);")

cur.execute("CREATE INDEX IF NOT EXISTS mx_int_mirna on mx_int (miRNA_family);")
cur.execute("CREATE INDEX IF NOT EXISTS mx_int_gene on mx_int (gene_family);")
cur.execute("CREATE INDEX IF NOT EXISTS mx_int_interaction on mx_int (interaction);")
cur.execute("CREATE INDEX IF NOT EXISTS mx_int_evs on mx_int (evidence_documents);")

cur.execute("CREATE INDEX IF NOT EXISTS mx_annot_doc on mx_annot (doc_id);")
cur.execute("CREATE INDEX IF NOT EXISTS mx_annot_concept on mx_annot (concept);")
cur.execute("CREATE INDEX IF NOT EXISTS mx_annot_annotation on mx_annot (annotation);")
cur.execute("CREATE INDEX IF NOT EXISTS mx_annot_occs on mx_annot (num_occurrences);")

cur.execute("CREATE INDEX IF NOT EXISTS mx_sent_doc on mx_sent (doc_id);")
cur.execute("CREATE INDEX IF NOT EXISTS mx_sent_sentid on mx_sent (sent_id);")

cur.execute("CREATE INDEX IF NOT EXISTS mx_dates_doc on mx_dates (doc_id);")

# %%
spark = None

# %%
if not "spark" in globals() or spark is None:
    print("Creating builder")
    spark = SparkSession.builder.\
            config("spark.executor.memory", "70g").\
            config("spark.driver.memory", "50g").\
            config("spark.memory.offHeap.enabled",True).\
            config("spark.memory.offHeap.size","16g").\
            config("spark.driver.maxResultSize", "4g").\
            config("spark.sql.shuffle.partitions", 300).\
            appName('mirexplore').getOrCreate()
# Out:
# Creating builder
# /mnt/extproj/projekte/bartelt/software/miniconda3/envs/mirexplore/lib/python3.6/site-packages/pyspark/context.py:238: FutureWarning: Python 3.6 support is deprecated in Spark 3.2.
#   FutureWarning

# %%
schema_int = StringType()

interaction_udf = udf(
    lambda x: ";".join([y for y in list(x)]),
    schema_int
)

def transform_sent(x):
    sents = []
    for y in list(x):
        docid = y[0]
        loc1 = y[1]
        loc2 = y[2]
        
        sents.append( str( (docid, tuple(loc1), tuple(loc2)) ) )
    
    return ";".join(sents)


sent_udf = udf(
    lambda x: transform_sent(x),
    schema_int
)

# %%
df_int = spark.read.parquet("/mnt/extproj/projekte/textmining/mx_feb24/mx_mirna_gene_consensus_parquet")
df_int.show(n=5)
# Out:
# +------------+-----------+----------------+---------+--------------------+--------------------+--------------+----------+------------+
# |miRNA_family|gene_family|     interaction|organisms|  evidence_documents|      sent_evidences|evidence_count|sent_count|is_consensus|
# +------------+-----------+----------------+---------+--------------------+--------------------+--------------+----------+------------+
# |    miR-8485|       INSR| {MIR_GENE, NEU}|  hsa;mmu|        [PMC5979287]|[{PMC5979287.3.54...|             1|         1|           1|
# |    miR-8485|       IRS2| {MIR_GENE, NEU}|  hsa;mmu|        [PMC5979287]|[{PMC5979287.3.54...|             1|         1|           1|
# |    miR-8485|      ITGAM| {GENE_MIR, NEU}|  hsa;mmu|        [PMC9639483]|[{PMC9639483.3.22...|             1|         1|           1|
# |    miR-8485|    LAMTOR3| {GENE_MIR, NEU}|  hsa;mmu|        [PMC9358144]|[{PMC9358144.3.15...|             1|         1|           0|
# |    miR-8485|    LAMTOR3|{MIR_GENE, DOWN}|  hsa;mmu|[35959437, PMC935...|[{PMC9358144.3.18...|             2|         3|           0|
# +------------+-----------+----------------+---------+--------------------+--------------------+--------------+----------+------------+
# only showing top 5 rows

# %%
df_intdoc = df_int.select(["miRNA_family", "gene_family", "interaction", "evidence_documents"]).withColumn("interaction", interaction_udf("interaction")).withColumn("evidence_documents", explode("evidence_documents"))
df_intdoc.show(n=5)
# Out:
# +------------+-----------+-------------+------------------+
# |miRNA_family|gene_family|  interaction|evidence_documents|
# +------------+-----------+-------------+------------------+
# |    miR-8485|       INSR| MIR_GENE;NEU|        PMC5979287|
# |    miR-8485|       IRS2| MIR_GENE;NEU|        PMC5979287|
# |    miR-8485|      ITGAM| GENE_MIR;NEU|        PMC9639483|
# |    miR-8485|    LAMTOR3| GENE_MIR;NEU|        PMC9358144|
# |    miR-8485|    LAMTOR3|MIR_GENE;DOWN|          35959437|
# +------------+-----------+-------------+------------------+
# only showing top 5 rows

# %%
df_int = spark.read.parquet("/mnt/extproj/projekte/textmining/mx_feb24/mx_mirna_gene_consensus_parquet")

df_cons2 = df_int.withColumn("interaction", interaction_udf("interaction"))\
                .withColumn("evidence_documents", concat_ws(";",col("evidence_documents")))\
                .withColumn("sent_evidences", sent_udf("sent_evidences"))
                
                #.withColumn("organisms", concat_ws(";",col("organisms"))) \

# %%
df_cons2.show(n=5)
# Out:
# +------------+-----------+-------------+---------+-------------------+--------------------+--------------+----------+------------+
# |miRNA_family|gene_family|  interaction|organisms| evidence_documents|      sent_evidences|evidence_count|sent_count|is_consensus|
# +------------+-----------+-------------+---------+-------------------+--------------------+--------------+----------+------------+
# |    miR-8485|       INSR| MIR_GENE;NEU|  hsa;mmu|         PMC5979287|('PMC5979287.3.54...|             1|         1|           1|
# |    miR-8485|       IRS2| MIR_GENE;NEU|  hsa;mmu|         PMC5979287|('PMC5979287.3.54...|             1|         1|           1|
# |    miR-8485|      ITGAM| GENE_MIR;NEU|  hsa;mmu|         PMC9639483|('PMC9639483.3.22...|             1|         1|           1|
# |    miR-8485|    LAMTOR3| GENE_MIR;NEU|  hsa;mmu|         PMC9358144|('PMC9358144.3.15...|             1|         1|           0|
# |    miR-8485|    LAMTOR3|MIR_GENE;DOWN|  hsa;mmu|35959437;PMC9358144|('PMC9358144.3.18...|             2|         3|           0|
# +------------+-----------+-------------+---------+-------------------+--------------------+--------------+----------+------------+
# only showing top 5 rows

# %%
df_cons2.select(col("organisms")).distinct().show()
# Out:
# +---------+
# |organisms|
# +---------+
# |  hsa;mmu|
# |      mmu|
# |      hsa|
# +---------+

# %%
df_sent = spark.read.parquet("/mnt/extproj/projekte/textmining/mx_feb24/mx_document_sentences")
df_sent.show(n=5)
# Out:
# +-----------+-----------------+--------------------+
# |     doc_id|          sent_id|            sentence|
# +-----------+-----------------+--------------------+
# |PMC10208224|PMC10208224.3.109|(B) Penalty plot ...|
# |PMC10208224|PMC10208224.3.110|(C) Distribution ...|
# |PMC10208224|PMC10208224.3.111|(D) The error var...|
# |PMC10208224|PMC10208224.3.112|(E) Identificatio...|
# |PMC10208224|PMC10208224.3.113|(F) 7 immune cell...|
# +-----------+-----------------+--------------------+
# only showing top 5 rows

# %%
def transform_sent2(x):
    sents = []

    for y in list(x):
        
        sentid = y["sent"]
        loc = tuple(y["loc"])
        
        sents.append( "{},{},{}".format(sentid, loc[0], loc[1]) )
    
    return "|".join(sents)


sent_udf2 = udf(
    lambda x: transform_sent2(x),
    schema_int
)

# %%
df_annot = spark.read.parquet("/mnt/extproj/projekte/textmining/mx_feb24/mx_document_annotations")
df_annot2 = df_annot.withColumn("num_occurrences", size("sent_evidences")).withColumn("sent_evidences", sent_udf2("sent_evidences")) #withColumn("sent_evidences", explode("sent_evidences"))
df_annot2.show(n=5, truncate=False)
# Out:
# +--------+------------+------------+----------------------------------+-----------------------------------------+---------------+
# |doc_id  |annotation  |concept_id  |concept                           |sent_evidences                           |num_occurrences|
# +--------+------------+------------+----------------------------------+-----------------------------------------+---------------+
# |15766526|GeneOntology|GO:0035925  |mRNA 3'-UTR AU-rich region binding|15766526.2.5,73,84                       |1              |
# |15944709|ncit        |NCIT:C38784 |Apoptosis Pathway                 |15944709.2.4,102,111|15944709.2.2,103,112|2              |
# |16096373|ncit        |NCIT:C18379 |E2F1 Gene                         |16096373.2.10,74,78|16096373.2.9,125,129 |2              |
# |16166262|ncit        |NCIT:C134463|BCL2 Positive                     |16166262.2.3,85,100                      |1              |
# |16227573|ncit        |NCIT:C80216 |Encode                            |16227573.2.1,24,30                       |1              |
# +--------+------------+------------+----------------------------------+-----------------------------------------+---------------+
# only showing top 5 rows

# %%
df_date = spark.read.parquet("/mnt/extproj/projekte/textmining/mx_feb24/mx_document_pubdates")
df_date.show(n=5)
# Out:
# +--------+----------+
# |  doc_id|      date|
# +--------+----------+
# |22473090|2012-04-04|
# |30070313|2018-08-01|
# |36322282|2022-11-02|
# |27121640|2016-04-28|
# |37025658|2023-03-21|
# +--------+----------+
# only showing top 5 rows

# %%
df_cons2.show(n=5)
# Out:
# +------------+-----------+-------------+---------+-------------------+--------------------+--------------+----------+------------+
# |miRNA_family|gene_family|  interaction|organisms| evidence_documents|      sent_evidences|evidence_count|sent_count|is_consensus|
# +------------+-----------+-------------+---------+-------------------+--------------------+--------------+----------+------------+
# |    miR-8485|       INSR| MIR_GENE;NEU|  hsa;mmu|         PMC5979287|('PMC5979287.3.54...|             1|         1|           1|
# |    miR-8485|       IRS2| MIR_GENE;NEU|  hsa;mmu|         PMC5979287|('PMC5979287.3.54...|             1|         1|           1|
# |    miR-8485|      ITGAM| GENE_MIR;NEU|  hsa;mmu|         PMC9639483|('PMC9639483.3.22...|             1|         1|           1|
# |    miR-8485|    LAMTOR3| GENE_MIR;NEU|  hsa;mmu|         PMC9358144|('PMC9358144.3.15...|             1|         1|           0|
# |    miR-8485|    LAMTOR3|MIR_GENE;DOWN|  hsa;mmu|35959437;PMC9358144|('PMC9358144.3.18...|             2|         3|           0|
# +------------+-----------+-------------+---------+-------------------+--------------------+--------------+----------+------------+
# only showing top 5 rows

# %%
df_int.show(n=5)
# Out:
# +------------+-----------+----------------+---------+--------------------+--------------------+--------------+----------+------------+
# |miRNA_family|gene_family|     interaction|organisms|  evidence_documents|      sent_evidences|evidence_count|sent_count|is_consensus|
# +------------+-----------+----------------+---------+--------------------+--------------------+--------------+----------+------------+
# |    miR-8485|       INSR| {MIR_GENE, NEU}|  hsa;mmu|        [PMC5979287]|[{PMC5979287.3.54...|             1|         1|           1|
# |    miR-8485|       IRS2| {MIR_GENE, NEU}|  hsa;mmu|        [PMC5979287]|[{PMC5979287.3.54...|             1|         1|           1|
# |    miR-8485|      ITGAM| {GENE_MIR, NEU}|  hsa;mmu|        [PMC9639483]|[{PMC9639483.3.22...|             1|         1|           1|
# |    miR-8485|    LAMTOR3| {GENE_MIR, NEU}|  hsa;mmu|        [PMC9358144]|[{PMC9358144.3.15...|             1|         1|           0|
# |    miR-8485|    LAMTOR3|{MIR_GENE, DOWN}|  hsa;mmu|[35959437, PMC935...|[{PMC9358144.3.18...|             2|         3|           0|
# +------------+-----------+----------------+---------+--------------------+--------------------+--------------+----------+------------+
# only showing top 5 rows

# %%
df_annot2.show(n=5)
# Out:
# +--------+------------+------------+--------------------+--------------------+---------------+
# |  doc_id|  annotation|  concept_id|             concept|      sent_evidences|num_occurrences|
# +--------+------------+------------+--------------------+--------------------+---------------+
# |15766526|GeneOntology|  GO:0035925|mRNA 3'-UTR AU-ri...|  15766526.2.5,73,84|              1|
# |15944709|        ncit| NCIT:C38784|   Apoptosis Pathway|15944709.2.4,102,...|              2|
# |16096373|        ncit| NCIT:C18379|           E2F1 Gene|16096373.2.10,74,...|              2|
# |16166262|        ncit|NCIT:C134463|       BCL2 Positive| 16166262.2.3,85,100|              1|
# |16227573|        ncit| NCIT:C80216|              Encode|  16227573.2.1,24,30|              1|
# +--------+------------+------------+--------------------+--------------------+---------------+
# only showing top 5 rows

# %%
df_sent.show(n=5)
# Out:
# +-----------+-----------------+--------------------+
# |     doc_id|          sent_id|            sentence|
# +-----------+-----------------+--------------------+
# |PMC10208224|PMC10208224.3.109|(B) Penalty plot ...|
# |PMC10208224|PMC10208224.3.110|(C) Distribution ...|
# |PMC10208224|PMC10208224.3.111|(D) The error var...|
# |PMC10208224|PMC10208224.3.112|(E) Identificatio...|
# |PMC10208224|PMC10208224.3.113|(F) 7 immune cell...|
# +-----------+-----------------+--------------------+
# only showing top 5 rows

# %%
df_cons2.toPandas().to_sql(name='mx', con=con, if_exists='append', index_label="index")

# %%
df_intdoc.toPandas().to_sql(name='mx_int', con=con, if_exists='append', index_label="index")

# %%
df_annot2.toPandas().to_sql(name='mx_annot', con=con, if_exists='append', index_label="index")

# %%
df_sent.toPandas().to_sql(name='mx_sent', con=con, if_exists='append', index_label="index")

# %%
df_date.toPandas().to_sql(name='mx_dates', con=con, if_exists='append', index_label="index")

# %%
a = cur.execute("SELECT * FROM mx ORDER BY evidence_count desc LIMIT 10")
for x in a:
    print(x)
# Out:
# (33004, 'miR-146a', 'TRAF6', 'MIR_GENE;NEU', 'hsa;mmu', 'PMC4355369;PMC4728582;PMC3864784;PMC4782155;PMC3296165;19596990;PMC8065171;PMC5209629;PMC4118904;PMC6894150;27889748;PMC6108336;PMC3896800;27904767;PMC5477577;PMC3977468;35836229;PMC4745677;PMC4690884;24962817;PMC9618628;PMC10470528;PMC7364237;PMC7012207;24809256;PMC5514914;PMC6132771;34601384;28720071;PMC6869321;PMC7564019;24022569;PMC10186648;PMC9036177;PMC3821651;PMC6527808;PMC4632746;PMC8005601;PMC5854688;PMC6026810;PMC4425084;PMC3728531;PMC3438039;PMC4271720;PMC5358779;PMC4881486;PMC6531989;PMC3521996;PMC9160310;PMC4087671;PMC9981676;PMC7598604;PMC9022539;PMC5356798;PMC9637324;PMC9359068;PMC10734085;38025715;29048658;PMC10284807;PMC4050406;PMC7177468;26458771;PMC4033429;33002743;31330207;PMC9319398;PMC6901988;25515214;PMC5297674;PMC7522358;PMC3827083;PMC9265316;PMC9972678;PMC5760497;PMC7222555;PMC10526236;PMC10669845;PMC9413930;PMC5406027;PMC5498339;PMC5703983;PMC7075948;29754557;PMC8084815;PMC2818025;PMC3342163;PMC3938074;27156837;26048146;34195795;PMC6370221;PMC5935709;PMC6539777;PMC4613317;33459883;PMC3949129;PMC3446449;PMC4260878;PMC2705851;PMC4505508;PMC4357424;PMC7330036;PMC5518530;35548775;24824805;PMC5025478;35777802;36175984;PMC3841223;PMC6829533;PMC10640847;PMC7642849;27546538;PMC5286482;PMC6389164;PMC6410298;PMC9673305;PMC6805641;PMC9849778;PMC5868594;33554730;PMC4730241;PMC10803576;PMC10413769;PMC9281091;35195809;PMC4423019;PMC7063117;PMC9405611;PMC4072100;PMC8230573;PMC7656297;PMC6698855;PMC5705777;36276993;PMC9898039;PMC7105721;20542134;PMC9922687;PMC6678954;PMC10471759;PMC9389495;PMC5067535;29693168;33717566;PMC4911355;PMC7644590;PMC10045117;PMC9511149;PMC5831915;PMC7070912;27845876;PMC6550192;PMC4812255;PMC8450356;PMC8130824;PMC8085756;PMC8385664;PMC7601058;PMC7025468;PMC2894768;PMC4595118;PMC9013931;PMC5377586;PMC6632112;PMC3505936;PMC10787510;PMC6522842;PMC10313823;PMC10354437;32633138;PMC6716825;PMC4884392;PMC6395003;PMC4085003;PMC5497632;33160737;PMC9732064;32996080;31098627;PMC8103001;PMC9783981;PMC5294386;PMC10125762;PMC6003571;PMC5408711;PMC9021632;PMC7493930;31805184;PMC9044847;PMC10295442;PMC10221045;PMC4742121;PMC4079695;PMC4641946;PMC3515505;PMC5994250;PMC7555060;PMC9736803;PMC3338094;PMC10803515;PMC2911870;PMC7369821;PMC10185836;PMC7218232;PMC9051029;PMC6685226;PMC6947565;PMC10294986;PMC10487837;PMC2911863;25205119;28858844;PMC5583156;PMC9957441;PMC7099408;PMC9551313;PMC3626297;PMC3595296;PMC7525504;PMC5334424;23252865;PMC5776175;PMC3976256;PMC5855987;PMC3639252;PMC4259436;28161709;PMC10017462;PMC10233054;PMC9130478;PMC10454149;PMC4680116;PMC8257678;32223462;PMC8430788;PMC7096474;PMC5898639;23794009;37101596;PMC7554994;PMC6460512;PMC6011198;PMC9637816;PMC3823654;PMC10440907;28587864;PMC8145252;PMC4356155;PMC5039188;PMC5021733;PMC4962986;28131813;PMC4237136;PMC9402903;PMC4779539;PMC5393898;PMC9108502;23208587;31656540;PMC10270362;PMC5968033;PMC3577724;PMC8303406;PMC5360757;PMC5108814;PMC4061830;PMC9952907;PMC5885483;30685530;PMC4383612;PMC10749346;PMC8004521;PMC5637866;22593544;PMC5799178;PMC9675566;PMC10488112;PMC6002112;26925748;PMC5771628;32328683;PMC3547332;PMC3660742;PMC6532024;PMC10322961;PMC7008714;26345941;29678844;PMC10512060;PMC9382584;PMC6963325;PMC6838115;PMC3996893;PMC3697994;PMC5833436;PMC4964452;PMC10058633;29288795;PMC6606704;PMC6480223;34100917;PMC5696148;PMC10756836;PMC4053854;PMC6028755;37392988;PMC10584721;30378773;PMC8440507;PMC8468560;PMC9586766;33531066;PMC9525760;PMC10227795;PMC5081962;PMC6753331;PMC2672161;PMC7222315;PMC7164639;PMC8188166;PMC4995328;PMC10005876;PMC9028838;PMC6399529;PMC9870706;PMC3884629;PMC6716067;PMC7397388;PMC6356052;PMC4460131;PMC6546822;PMC8268546;PMC3693036;PMC9749272;PMC8243333;PMC9352948;PMC6642776;PMC3200075;PMC9427301;PMC3629121;PMC4564244;PMC5435729;23244216;PMC7077053;PMC7179762;PMC7320068;PMC9941745;PMC5994557;32110074;PMC4728571;PMC4745861;PMC9464867;PMC6129849;PMC7086345;PMC10196196;PMC8346058;30611999;PMC6942290;PMC5377073;PMC6554415;PMC7493784;PMC8193882;PMC6504686;PMC4240164;34749 ...
# (30911, 'miR-146a', 'IRAK1', 'MIR_GENE;NEU', 'hsa;mmu', 'PMC4355369;PMC4728582;PMC3864784;PMC4782155;PMC3296165;19596990;PMC6468559;PMC5963611;PMC4118904;PMC6894150;PMC4342515;PMC8172566;PMC6108336;PMC3896800;PMC5477577;PMC3977468;30060033;PMC4745677;PMC4690884;24962817;PMC9618628;PMC10470528;PMC7364237;PMC7012207;24809256;PMC4841580;PMC5514914;PMC6132771;34601384;PMC6869321;PMC3672198;PMC7564019;PMC4630578;PMC10186648;PMC9593037;PMC4632746;PMC8005601;24561744;PMC5854688;PMC6026810;PMC3728531;20500689;PMC3438039;PMC4271720;33256301;PMC5358779;PMC3493483;PMC4881486;PMC7178317;PMC3521996;PMC4087671;PMC9981676;PMC9686412;PMC2919253;PMC9022539;PMC9637324;PMC9359068;PMC10284807;PMC4050406;PMC7177468;PMC8079678;PMC10457161;PMC4033429;PMC5365120;31330207;PMC9319398;PMC5297674;PMC6021342;PMC3827083;PMC9265316;PMC9972678;PMC5760497;PMC7222555;PMC10526236;30308218;PMC10669845;PMC9413930;PMC5406027;PMC8084815;PMC2818025;PMC3342163;PMC5341923;26048146;PMC6539777;PMC6370221;PMC5935709;PMC4613317;PMC3949129;PMC4260878;PMC2705851;PMC7330036;24824805;35777802;36175984;PMC3841223;PMC6829533;27546538;PMC5286482;PMC6410298;PMC9673305;PMC6805641;30675215;PMC8087853;PMC5868594;33554730;PMC4730241;PMC10803576;PMC6347606;PMC10413769;35195809;PMC4423019;PMC9405611;PMC5032686;PMC8230573;PMC6698855;PMC5705777;PMC9898039;33380238;PMC4845539;PMC7105721;20542134;PMC9922687;PMC3982050;PMC10471759;PMC9389495;PMC5067535;29693168;PMC5607273;33717566;PMC4911355;PMC7644590;PMC10045117;PMC9511149;PMC5831915;PMC7070912;27845876;PMC6550192;PMC8450356;28207326;PMC8085756;PMC8385664;PMC7601058;PMC7025468;PMC2894768;PMC4016853;PMC4595118;PMC7290936;PMC10529274;PMC9013931;PMC5377586;PMC3688919;PMC6632112;PMC3505936;PMC5945810;PMC10787510;PMC8447760;PMC6522842;PMC10313823;PMC10354437;PMC5021476;PMC4884392;PMC3608584;PMC8482139;30701447;PMC5497632;33160737;31098627;PMC8103001;PMC9783981;PMC5294386;PMC10125762;PMC10589634;PMC10329313;PMC9021632;PMC7493930;31805184;PMC10295442;PMC10221045;PMC6058186;PMC4079695;PMC4641946;PMC3515505;PMC5994250;PMC8056184;PMC5833376;PMC6856662;PMC3338094;PMC7369821;PMC7218232;PMC9051029;PMC10487837;PMC2911863;28858844;PMC5583156;PMC10216432;PMC9957441;PMC7099408;PMC3465251;PMC3626297;PMC10642248;PMC6969641;PMC4791239;PMC3595296;PMC5334424;23252865;PMC5776175;PMC3976256;PMC5855987;PMC3639252;PMC9938762;PMC10017462;PMC8222190;36274319;PMC9130478;PMC10454149;PMC8257678;32223462;PMC5898639;23794009;37101596;PMC4454760;PMC7554994;PMC6460512;PMC6011198;PMC3823654;PMC6435682;PMC10440907;28587864;PMC8145252;PMC4356155;PMC5021733;PMC4962986;28131813;PMC8005705;PMC4237136;PMC9402903;PMC4779539;PMC4691177;PMC3789763;23208587;PMC9142309;PMC10270362;PMC5968033;PMC3577724;PMC8065643;PMC5360757;PMC5108814;21640790;PMC4061830;PMC9952907;30685530;PMC4383612;PMC9146752;PMC6880603;PMC10749346;PMC5637866;22593544;PMC5799178;PMC4042463;PMC3531605;33259730;PMC6002112;26925748;PMC10488112;PMC5771628;32944178;24867582;PMC3660742;PMC6532024;PMC4202709;PMC10322961;29678844;PMC6963325;PMC6838115;30707940;PMC3996893;PMC5833436;PMC4964452;PMC10058633;29288795;PMC6606704;PMC6480223;PMC5696148;PMC10756836;PMC4053854;PMC8468560;PMC4814683;24142285;23727324;PMC10227795;PMC6753331;PMC7017296;PMC4995328;PMC10005876;PMC9028838;PMC4210915;PMC6399529;PMC9870706;PMC7397388;PMC7564652;PMC9846267;21632853;PMC8268546;PMC3693036;PMC6642776;27188726;PMC3200075;PMC3629121;PMC5352187;PMC4564244;PMC5368693;31630447;PMC5435729;PMC3565163;23244216;PMC7077053;PMC7179762;PMC7320068;PMC5994557;32110074;32935891;PMC4728571;PMC4745861;PMC9464867;PMC6129849;PMC7086345;PMC8346058;PMC6942290;PMC5377073;PMC7493784;PMC8193882;PMC4240164;34749364;20937840;PMC6863924;34981334;PMC9699533;PMC9504570;PMC3766675;PMC8391642;36160881;PMC3940969;PMC5539227;PMC3659470;PMC5371387;PMC4585786;PMC5991072;PMC4848994;PMC6063882;20524934;32803682;PMC7391576;PMC6406975;PMC6066587;PMC8096907;PMC4519843;PMC5483987;PMC3634477;PMC4245999;PMC4557301;PMC9890888;PMC10336050;PMC9065182;PMC7573146;PMC6610989;PMC6048122;PMC38 ...
# (44349, 'miR-34a', 'SIRT1', 'MIR_GENE;NEU', 'hsa;mmu', 'PMC10346838;32010268;PMC3229974;PMC9250967;PMC5660088;PMC4617708;PMC8057887;PMC5496266;PMC6049505;PMC6859113;PMC7236805;PMC9600935;30474870;PMC6468660;33098868;PMC8489683;PMC9064850;PMC9289798;PMC9044750;PMC7349658;PMC8102505;PMC9367537;PMC7429713;PMC6406262;37146843;31295467;PMC5462749;PMC4331324;PMC4356452;PMC5337313;PMC4650741;PMC3779207;PMC7555602;33932899;PMC10042704;PMC3588074;PMC9178824;PMC4951325;27789474;PMC4810101;PMC9977821;PMC2919253;28514495;PMC6722391;PMC4225545;33488795;PMC8234685;25286678;PMC6627372;31092575;PMC5094942;PMC9818427;PMC5485288;33894312;PMC10064073;PMC4924752;PMC7395409;PMC8378762;PMC6888083;PMC9473659;PMC7459507;PMC5535855;PMC3829672;PMC9820400;PMC4882481;PMC4503669;PMC4342799;PMC6461183;PMC6358728;35561843;PMC7072921;PMC7378626;33937961;PMC9791179;PMC4503872;PMC8265106;PMC9695749;26082557;PMC9817684;PMC10253051;PMC10351381;PMC5659022;25015333;27979858;PMC6457055;PMC5644184;PMC6829533;PMC9406349;PMC4519945;PMC9500079;35105933;PMC7160647;PMC5115889;PMC10085612;PMC10281530;33763423;PMC6468509;22623155;PMC6929013;PMC4877571;PMC3643940;21067862;PMC3213093;PMC7352701;PMC9136398;PMC9849909;PMC5010605;PMC7554851;PMC7381749;PMC9019216;PMC10418327;PMC3997725;PMC4660435;33064974;PMC6201502;26518892;PMC7140545;37819016;PMC10488769;PMC9084317;PMC9181031;PMC4200826;PMC3860425;PMC10669115;PMC5751299;PMC5976482;25526086;PMC9611907;PMC3907875;PMC7052494;PMC4177398;35958481;PMC6394539;PMC10527269;PMC9637765;32461691;PMC6940935;PMC7048222;PMC8286668;32057805;PMC8223511;36583714;PMC4065722;PMC3850795;PMC6950227;22027593;PMC3930407;PMC7554858;PMC4121398;PMC10252239;PMC6978795;PMC5497632;PMC4404052;PMC4605485;22364258;PMC8425090;PMC9576479;PMC7195659;PMC9626984;PMC5962651;31927917;PMC3153928;37467842;PMC4353379;PMC9929468;PMC9445363;PMC8303854;PMC9563608;PMC6567918;PMC6927948;PMC4789259;PMC4846847;PMC6406308;PMC10276617;PMC9797940;36926729;PMC8046563;PMC3166078;PMC7573351;PMC5001249;33661552;PMC9820363;PMC6966446;PMC9497236;PMC5756562;PMC8194257;PMC5836070;PMC10233054;PMC7501554;PMC9162978;PMC10012483;PMC5841108;PMC5408604;PMC4557122;PMC10296615;PMC10696434;PMC3171461;PMC5605522;25896587;PMC3464169;PMC4159383;PMC6815544;PMC5893820;PMC10414636;PMC10541324;PMC10178434;35835182;PMC8397000;33400820;PMC6769710;PMC6282400;PMC5209603;PMC9155922;PMC3588049;25452565;PMC7503821;PMC6121310;PMC6320931;PMC9186770;PMC6321452;PMC7279254;PMC5355173;PMC6371621;PMC10377597;27990356;PMC5362489;PMC8393918;PMC10741778;PMC5572399;PMC6761099;PMC8199164;PMC4763196;PMC6266715;PMC8017203;PMC9106007;PMC3360657;PMC4368136;PMC10379376;PMC9883885;31333735;PMC9024590;PMC7573826;20439489;PMC8175718;PMC6499230;PMC4307318;PMC6935448;28899784;26582729;30030567;PMC9123752;PMC8450503;PMC7046075;22841474;PMC9610703;PMC7281179;PMC6584679;PMC5386729;PMC9561951;25489229;PMC6098056;PMC6967090;PMC5863891;PMC2997008;PMC5661652;PMC9738374;PMC10138011;PMC3497334;34520170;PMC7641266;PMC7408939;PMC5772851;PMC6036139;18755897;PMC3794730;PMC3358265;PMC7489042;PMC3606220;PMC5058779;PMC8358062;33718673;PMC10671451;PMC6816564;PMC6834183;PMC5081962;PMC3448677;PMC10791979;PMC9659888;33380310;PMC7059652;PMC8263289;PMC4638174;PMC4159023;PMC3912349;PMC4065264;PMC9389718;PMC5116671;23361983;30555597;PMC4881607;PMC5187803;PMC3972908;26718338;24548601;PMC7645065;PMC10561733;PMC9749272;PMC7098911;PMC8147843;PMC3608239;PMC6631275;PMC5466768;PMC8000568;PMC6320903;PMC10753178;PMC9690481;PMC3788732;32566017;PMC6859532;PMC6813187;PMC6744582;PMC9561330;PMC7343704;PMC5731849;31296380;PMC9515360;PMC10354256;PMC4477183;PMC7248367;PMC9504570;36577153;PMC10669494;PMC6719220;PMC9251114;PMC5266863;PMC6121276;PMC5707640;PMC4597437;PMC8101138;PMC8033173;PMC10333929;PMC5342681;PMC8368219;PMC6015721;23032974;PMC7093192;PMC7407379;PMC7140035;PMC10073704;PMC6723080;PMC4881491;PMC6278132;24832395;PMC4663478;PMC4670458;PMC10142204;PMC6770964;PMC5322748;25865700;PMC5516006;37026704;PMC9254375;33492448;PMC10571940;PMC3463915;PMC8166991;27247228;2 ...
# (44351, 'miR-34a', 'SIRT1', 'MIR_GENE;DOWN', 'hsa;mmu', 'PMC6769631;PMC3229974;PMC6271734;PMC5203917;30968966;PMC10510481;PMC5496266;PMC7000655;34698884;PMC10577960;PMC9600935;PMC6031650;PMC5760504;PMC2780389;33098868;PMC8489683;PMC7229769;PMC4926343;PMC5348533;PMC8102505;PMC7352675;PMC6406262;PMC10164299;32114390;31295467;PMC9377967;PMC5462749;PMC5337313;PMC4650741;PMC7555602;33932899;PMC10042704;PMC4589759;PMC3588074;23954321;PMC8232095;PMC9313249;PMC9178824;PMC4951325;27789474;PMC9977821;36058294;PMC10045733;PMC7581848;29556386;PMC8234685;PMC6357050;PMC6170877;PMC6876316;PMC5094942;30880751;PMC9818427;PMC5485288;33894312;PMC8490502;27639250;24249224;PMC9207305;PMC9688578;PMC7459507;PMC6952878;PMC9340262;PMC3386918;PMC4394469;PMC3285660;PMC5670231;28810936;PMC9820400;PMC5937771;PMC4503669;PMC6461183;PMC4100099;PMC3281867;PMC9779323;PMC9695749;PMC5343073;PMC10157232;20424141;PMC9817684;PMC9855573;PMC10143523;PMC6123370;PMC4059663;PMC7347005;PMC5658440;PMC5983804;27208501;PMC9818030;PMC5777732;PMC9406349;PMC5237128;PMC9500079;23834033;35105933;PMC6928693;PMC7348976;PMC5115889;PMC8183992;PMC10085612;PMC10135683;PMC8052565;PMC7350193;33763423;PMC6501137;PMC10512576;22623155;PMC4877571;34088068;PMC3643940;21067862;PMC4451970;PMC6862076;PMC6695669;PMC7554851;PMC3997725;PMC5509453;PMC5814159;PMC6509231;PMC9198215;PMC4660435;PMC8446062;33064974;33517853;PMC7140545;PMC5600967;PMC10488769;PMC2956090;PMC9084317;PMC9181031;PMC6981696;PMC7052494;PMC4177398;31760527;PMC6394539;PMC7285661;PMC10527269;PMC9554963;PMC8218919;PMC6940935;PMC9760856;PMC10529274;PMC8223511;PMC5377586;PMC2806013;PMC3850795;PMC3616200;PMC8256167;PMC3930407;PMC9677683;PMC8380168;PMC9138026;PMC10252239;PMC5497632;PMC9688847;22560219;PMC4605485;PMC9139524;PMC3427493;PMC5652784;PMC3153928;37467842;PMC4353379;PMC6225658;PMC9530142;PMC7312021;PMC9563608;PMC7291448;PMC9227902;PMC9817765;PMC4443788;PMC4846847;PMC8347110;PMC9797940;PMC9561980;36926729;PMC8046563;PMC10698091;PMC8340535;PMC4009326;PMC3166078;PMC5664082;PMC7573351;PMC6961769;PMC6969641;PMC9319505;PMC9035591;PMC6068727;PMC6966446;PMC9497236;PMC5756562;PMC10449301;PMC5753510;PMC6717636;PMC10012483;PMC5841108;PMC5972018;PMC5408604;PMC4557122;PMC6718901;PMC3171461;PMC8046979;PMC5605522;PMC6164944;PMC4159383;PMC6815544;PMC6909457;PMC6127951;PMC10414636;28263817;35835182;PMC6433939;PMC6769710;PMC5209603;PMC5579695;25982144;PMC9720152;PMC6121310;PMC6320931;PMC9081650;PMC3157434;29928373;PMC3899709;PMC5674931;PMC6371621;32657157;27990356;PMC10377597;PMC7556287;PMC5053662;PMC8393918;PMC4763196;33155431;PMC3878201;37237862;PMC6266715;PMC8017203;PMC4671655;PMC9168231;PMC4368136;PMC3431991;PMC8156532;PMC9883885;PMC7573826;22902550;PMC9347108;25352462;PMC7084838;PMC6163567;PMC3082551;PMC8326758;PMC6499230;25395581;30030567;PMC4586453;PMC5807592;PMC7046075;PMC10762801;PMC7072652;PMC6584679;PMC9610703;25489229;PMC6098056;PMC5863891;PMC9012736;PMC9738374;34679437;PMC2289817;PMC3497334;PMC7641266;23759586;32634429;30026277;PMC9737485;PMC9289671;PMC5772851;PMC5738363;PMC10584721;PMC7601022;18755897;27126903;PMC9961959;PMC3358265;PMC8457614;PMC3606220;PMC6134555;PMC9525760;PMC5295001;PMC6816564;PMC3448677;30632134;PMC10791979;33380310;PMC4787051;PMC7477680;PMC5355356;PMC4638174;PMC3912349;PMC9389718;PMC5116671;30555597;PMC8110204;PMC5081972;PMC7094200;PMC10424510;PMC10209419;PMC7047711;PMC9516229;PMC9357903;PMC7098911;PMC6830080;PMC7352793;PMC3608239;PMC6631275;24759152;PMC5344225;PMC8000568;33507132;PMC8315851;PMC10753178;25638533;PMC3788732;PMC4204997;PMC3038978;PMC2705852;24480449;PMC10669459;PMC10621324;25348795;PMC8008071;PMC9737617;24970682;PMC6813187;PMC5731849;31296380;PMC9515360;PMC10354256;PMC5083978;PMC9504570;PMC5869503;28699360;PMC5187868;PMC6719220;PMC9251114;PMC4597437;PMC10744268;PMC8101138;PMC8150574;PMC5342681;PMC6015721;PMC7016867;PMC4438141;PMC7407379;PMC4357380;PMC9741793;PMC10073704;PMC4039115;PMC6278132;PMC4663478;PMC5696196;PMC6770964;PMC5601167;37026704;PMC7664704;PMC7109299;33492448;PMC10045866;PMC67697 ...
# (55913, 'miR-155', 'SOCS1', 'MIR_GENE;NEU', 'hsa;mmu', 'PMC3296165;PMC6271734;PMC5573731;PMC6535863;PMC5219823;PMC9080266;PMC3977468;PMC3717805;PMC9360006;PMC10418969;PMC7298347;23601686;PMC10232878;PMC8283767;PMC8347893;PMC5143393;PMC4632746;PMC5636846;25916938;PMC9139988;PMC4881531;PMC9120428;PMC10206140;PMC10048672;24963279;PMC4700747;23428672;29792529;PMC9118538;PMC5760508;PMC10095543;PMC4529177;PMC10243549;PMC8308226;PMC10052528;PMC9102350;PMC10500308;PMC6627372;PMC6563126;PMC6011077;PMC3219661;PMC7464680;PMC4216117;PMC3849775;PMC4583437;37298078;PMC4378312;PMC9543708;34675627;PMC9458373;PMC5103429;PMC5932537;28875362;29079998;PMC4879221;PMC7017057;25488154;PMC6155914;32173634;PMC9238060;PMC9405550;PMC6117380;PMC3529674;PMC7222555;PMC9512106;PMC9767356;PMC5498339;PMC4209600;PMC6791076;PMC6370221;PMC3739772;PMC10413105;PMC5983804;PMC10782702;PMC3098162;PMC5286482;21802214;PMC7062708;PMC7656123;PMC10803576;PMC8104413;PMC6537929;29349567;PMC6456606;PMC6105636;PMC2743997;PMC4905593;20354188;23956210;PMC7332777;PMC6271560;PMC4415416;28359146;PMC9920355;PMC9208551;25811992;27371731;PMC7352701;PMC9646755;PMC9686122;PMC7688008;PMC8122504;PMC6698855;PMC6130682;PMC7145947;PMC5028059;PMC4112849;PMC9180692;PMC3063410;PMC7360798;PMC9989161;PMC6790912;PMC6678911;PMC9525116;PMC5831915;PMC6478321;PMC8450356;PMC5173167;PMC5614978;PMC8206073;PMC5320745;30577275;22771905;PMC4695126;PMC8365877;PMC9270349;PMC9963874;PMC10702758;PMC10773759;PMC6988224;PMC10529274;PMC6632112;PMC4684403;PMC4477309;PMC4521145;PMC4496207;PMC6522842;PMC10322668;27817193;PMC5949326;PMC5400654;PMC9091820;29805490;PMC7412373;PMC5599032;PMC7505259;PMC9351994;25850724;PMC10693016;PMC10342854;PMC9736803;PMC8228670;PMC7050126;PMC10803515;PMC5033371;PMC5295016;PMC5041507;PMC9322748;PMC6280292;PMC3169510;PMC7525504;PMC4621458;PMC7003359;24778118;PMC4495342;PMC5609911;PMC10449301;PMC10092772;PMC9213139;PMC9387810;PMC7509487;PMC9585453;PMC5103287;37047769;36632777;PMC7179228;PMC5217048;PMC9937765;PMC5834423;PMC7387371;32116077;PMC9100906;PMC3876085;PMC4147158;PMC10817396;PMC9021302;PMC3857526;PMC8147237;PMC5540954;PMC9523483;PMC7582863;PMC7522940;PMC10440907;PMC5085116;19144316;PMC9818028;PMC8193853;PMC9914104;PMC8117219;PMC4962986;PMC7509534;PMC3063194;PMC9868426;PMC5765282;37219532;30639520;PMC3694260;PMC5418855;PMC8121812;PMC9106007;PMC10317017;PMC9716653;PMC9016041;PMC8393695;PMC9952907;PMC4971075;PMC5015201;PMC6842511;PMC5637866;PMC9148251;34190442;PMC7403463;PMC8220200;PMC5852581;PMC9577297;PMC3577898;PMC3566999;PMC4202709;PMC4099493;PMC6499178;25231976;PMC10512060;PMC4307358;PMC5343825;PMC6416164;PMC4678211;32707297;PMC3497334;PMC9659277;PMC8137895;PMC9081983;25550988;22634176;PMC10304259;PMC8492692;PMC8210670;32289665;PMC7291112;PMC6912477;20937844;PMC3559333;32634427;PMC5943557;PMC9588333;PMC4675784;PMC10144019;PMC5085149;PMC4500956;PMC6753331;PMC10791979;PMC9765511;PMC5446123;PMC10486026;36946346;PMC9331563;PMC9028838;PMC7154100;PMC6517388;PMC6530353;25761610;PMC5636984;PMC9319717;PMC5775309;31675124;31405809;PMC4482047;PMC3718810;PMC7522905;PMC10209419;PMC5829058;26159489;PMC9749272;PMC3693036;PMC10201773;PMC10180522;PMC7151598;PMC4504038;25998827;35545753;35157222;PMC9665326;PMC9963913;PMC7574442;PMC5652785;PMC5522316;PMC9143965;PMC10351202;PMC8414775;21806946;PMC5296614;PMC9257640;PMC3259120;PMC9455804;PMC5377073;PMC4463604;PMC5864932;PMC3741136;37842165;PMC10530247;PMC5691772;PMC6863924;PMC9504570;31182615;PMC9465299;PMC5797736;22170100;PMC6114258;31207208;24103701;PMC9445622;PMC4538424;PMC5309223;PMC5532436;PMC6606715;PMC5238459;PMC9970239;34900737;PMC10347850;PMC6002743;PMC7544739;PMC4837569;PMC7456828;PMC5896204;PMC6593301;PMC4694781;PMC7583886;PMC7664704;PMC5598939;PMC6317263;PMC5099153;PMC5999732;PMC10435084;PMC9204882;PMC4823043;PMC10410956;PMC7019373;PMC9885171;PMC10158024;PMC3101234;PMC5601671;PMC4575730;PMC9445982;PMC5964585;PMC10643230;PMC7349327;PMC8264550;PMC6169013;PMC9698371;PMC2835996;PMC6163993;PMC5650678;PMC9820302;PMC6721572;PMC3602184;PMC71459 ...
# (44998, 'miR-34a', 'TP53', 'GENE_MIR;NEU', 'hsa', 'PMC6336680;PMC7140525;23036084;PMC3996893;PMC2289817;PMC3996063;PMC9408007;PMC6271734;PMC9250967;PMC5973863;PMC5123406;PMC5342385;PMC4981319;PMC8230660;PMC5678797;18755897;PMC6085646;PMC7140674;PMC3120797;PMC4406127;PMC3358265;20118199;PMC6031650;PMC3606220;PMC4516245;PMC6468660;PMC6162501;PMC3229581;PMC6862169;PMC6912477;PMC9956318;PMC5374322;PMC6816564;24739178;PMC3448677;22436728;PMC10488243;PMC8239963;33875349;PMC6038585;PMC9760949;30515607;PMC10164299;PMC10649013;PMC6073392;19773441;19347736;PMC8037498;25217526;PMC4331324;PMC5462749;28435028;PMC5920438;PMC4210915;PMC3311059;PMC10093226;PMC3457075;PMC6826406;PMC9429775;PMC6360685;PMC7226288;PMC6039486;PMC7302353;PMC9763277;PMC3283527;PMC9002436;PMC3880257;32304779;PMC3546719;PMC4739602;PMC9147802;PMC3972908;PMC4873990;PMC6477741;PMC5429732;24548601;PMC3824358;PMC3793929;PMC5081972;PMC7645065;PMC3810591;PMC4225545;PMC3157715;PMC4390187;21448283;PMC9027424;PMC6470623;PMC9986462;PMC5963783;PMC9791775;PMC10341806;PMC10348419;33763422;PMC4260944;PMC3622605;PMC8378762;PMC9103757;PMC4914250;PMC7459507;PMC10219330;PMC3313940;PMC9619056;PMC4139009;PMC2841584;PMC3829672;PMC5297851;PMC3038978;PMC3406012;PMC2705852;PMC5787261;PMC3847369;PMC6953059;PMC7140102;PMC4394469;32285757;PMC9865746;PMC9736171;PMC5937771;PMC4599241;PMC8008071;PMC4503669;17996645;30944658;PMC6461183;26969487;PMC7072921;PMC8480024;PMC10406948;34999254;24832862;24402874;PMC5938044;PMC9519946;PMC4014081;PMC10591486;27450916;PMC9830510;PMC7400540;PMC5756259;26403328;PMC7460013;PMC6852927;PMC3525943;PMC5668003;PMC7487566;PMC3037971;PMC10110844;PMC10157232;PMC3070685;PMC6325163;PMC6003936;21240262;PMC2952964;PMC5659022;PMC5632457;25932212;PMC2892453;23759592;PMC9495382;PMC4462886;PMC6995379;PMC5342681;PMC9406349;PMC3240594;PMC4246619;PMC10388388;PMC7159826;19461653;PMC3964221;PMC4859802;PMC8058364;PMC3213160;PMC5868594;PMC7398912;PMC2864251;PMC10073704;PMC3154488;PMC4039115;PMC4663478;PMC10281530;PMC7600503;PMC5400590;PMC2690402;PMC5226533;PMC3537581;PMC3509128;PMC5620323;PMC3713000;PMC7318489;PMC9240017;PMC3213093;PMC5358472;PMC6103530;PMC4663477;PMC4451970;20883704;PMC4754861;PMC3157336;PMC7528083;PMC9149963;PMC10571940;PMC3192659;PMC3997725;PMC4148126;PMC2761947;PMC6826510;PMC9407881;PMC8345673;PMC5705777;PMC4186586;17540599;PMC4021670;PMC9068181;PMC4091869;PMC10307888;PMC2883962;PMC2956090;PMC6885777;PMC6098920;PMC7566714;PMC4637322;PMC5095069;PMC2954045;PMC4693153;PMC3313897;PMC5935984;PMC4177398;PMC5877782;PMC4203685;31235998;PMC10607732;PMC7246662;PMC4477414;PMC4054680;PMC8198729;PMC4862407;PMC4414168;17540598;PMC5751361;PMC5796207;22198213;PMC4963207;PMC5442347;PMC3498227;PMC4332424;PMC3446343;31258013;PMC5100479;PMC4065722;PMC6206098;PMC5584326;23860128;33438362;PMC4033189;PMC10379962;PMC5406713;PMC10297903;PMC9099786;PMC6769685;PMC4586775;PMC7590204;PMC4101396;PMC9600261;PMC7020748;26778750;PMC4404052;PMC3508619;PMC10824707;PMC4385600;PMC5312334;PMC5777811;PMC3615155;PMC5406860;PMC4278269;PMC10178135;PMC3794731;PMC5270669;PMC3942411;PMC5749745;PMC3153928;32763292;PMC6048189;PMC5922383;PMC4872728;17554199;PMC6205583;PMC6284860;23862748;PMC5855669;PMC7092992;PMC3824539;PMC9199308;PMC4891129;PMC9737083;PMC4546448;28624481;PMC5053736;PMC9227902;PMC6690672;PMC10321292;PMC10070433;PMC3852614;PMC4652991;PMC3120860;24319262;PMC3166078;PMC4951323;PMC5664082;PMC4057237;PMC3795376;PMC2716485;PMC5041507;PMC6961769;PMC4199480;PMC4011589;PMC4445322;PMC10048981;PMC8392400;PMC9954576;PMC5945834;PMC9715346;PMC9953219;PMC3198844;30899304;19373781;PMC4381606;PMC8075582;PMC6615213;PMC3583555;PMC9497236;PMC10233054;20089965;PMC5187829;PMC6838078;PMC6312226;PMC9266862;PMC10725964;PMC4547013;PMC6855070;PMC10296342;23569431;29748184;25916635;PMC3931274;PMC5682661;PMC5421894;PMC4491673;22531959;PMC10296615;18719384;PMC8327150;PMC3171461;PMC7554994;25896587;PMC5359838;PMC3464169;PMC10458232;PMC8177468;PMC3821625;PMC3575633;PMC3956911;PMC6030072;PMC5763532;PMC4921838;PMC5493669;PMC3289 ...
# (55912, 'miR-155', 'SOCS1', 'MIR_GENE;DOWN', 'hsa;mmu', 'PMC8476879;PMC4566032;36816357;32946211;PMC9485608;PMC3296165;PMC6468559;PMC9659277;PMC9686644;PMC5209629;PMC6535863;PMC5219823;PMC6270988;PMC6468348;PMC9080266;22634176;PMC3977468;PMC6443804;PMC4561113;PMC10705678;PMC8492692;PMC4053854;PMC5355168;PMC6036139;32289665;PMC7298347;PMC10340268;25185784;PMC10041730;PMC9406714;PMC2905360;23601686;PMC7020053;PMC10720180;PMC6966445;37059377;PMC9237338;32634427;PMC7466815;PMC9588333;PMC5143393;PMC9723351;28584078;PMC6032097;PMC5492016;PMC6753331;35563301;PMC9104938;PMC6038585;PMC9777375;PMC5636846;PMC6406262;PMC5446123;28004106;36946346;PMC7154100;PMC9028838;PMC10048672;23316018;24477912;25761610;PMC10525983;PMC5355356;PMC7404104;32547033;PMC6308157;PMC3745967;PMC3876682;PMC9922830;PMC5775309;19699171;29792529;PMC8067583;PMC9367505;PMC9118538;23436936;PMC5760508;PMC9981676;PMC4482047;PMC4810101;PMC3718810;PMC7300210;PMC7442402;PMC3976820;PMC5829058;26159489;PMC9749272;PMC5504619;PMC10052528;PMC8121735;PMC10500308;PMC6642776;PMC4504038;PMC9468484;PMC9130582;36121133;35157222;PMC4583437;PMC6631275;PMC7177468;PMC9963913;PMC3560369;PMC9458373;PMC7568790;PMC7053181;PMC3866655;PMC5103429;PMC5932537;PMC4463731;PMC6314626;PMC9043318;PMC4879221;PMC5311865;PMC8414775;PMC3695057;21806946;30468477;PMC4666359;PMC9207397;25488154;35111073;32173634;PMC8347112;PMC3529674;PMC9167543;PMC10491896;PMC3741136;37842165;PMC10530247;PMC10544417;23613163;PMC10669845;PMC6863924;PMC9504570;PMC6791076;PMC5797736;PMC6539777;PMC6904280;30905633;31207208;24103701;PMC6801828;PMC5707640;37327858;PMC9134914;PMC5983804;26620207;PMC5025478;PMC10085744;PMC7284431;PMC10393252;PMC4695119;PMC9234271;PMC5532436;PMC5238459;PMC8096907;PMC10138604;PMC9970239;PMC4534598;34900737;21802214;PMC8121453;PMC10347850;PMC6002743;PMC3468565;PMC9525109;PMC5575603;PMC7062708;PMC7544739;PMC6722206;PMC7266293;PMC6537929;29349567;37761144;PMC8194268;PMC6141694;PMC2743997;PMC4415416;PMC10036582;PMC9563138;PMC10051064;PMC7352701;PMC9208551;PMC8131104;PMC9646755;PMC7688008;PMC7583886;PMC8122504;PMC5598939;PMC6130682;PMC4991458;PMC6317263;PMC9730277;PMC5326496;PMC7145947;PMC5028059;PMC7226566;PMC10169341;PMC9204882;PMC10435084;PMC4823043;PMC3082546;PMC4510656;PMC7244143;PMC9271994;30721702;PMC3406950;PMC5357489;23572582;PMC9525116;22546503;PMC5831915;PMC3822588;PMC9780829;PMC4812255;PMC5173167;PMC5614978;24876306;PMC4575730;PMC5964585;PMC6169013;30577275;PMC7601058;PMC6678487;PMC9698371;PMC4315036;PMC4332424;PMC6134023;PMC7406792;PMC4684403;PMC5650678;PMC9820302;PMC6896161;PMC5945810;PMC3759953;PMC3602184;PMC4496207;PMC6522842;PMC8256167;26841929;PMC6753386;PMC6941309;27817193;PMC4693280;PMC6537751;PMC5949326;PMC5356677;PMC2994816;PMC9323912;PMC9496720;PMC9608867;PMC5742520;PMC8068787;31948528;28129114;29805490;PMC7139820;37087792;PMC10735715;PMC5599032;PMC7412373;PMC6749156;PMC9554277;PMC4881540;PMC4075993;PMC4169426;PMC3749101;PMC9351994;PMC9332365;PMC4924278;PMC6891702;PMC10693016;PMC5098093;PMC5514092;PMC9389448;PMC7678062;PMC9007653;PMC8044831;PMC3338496;PMC7306520;25502838;PMC6617214;PMC9495355;35542211;PMC7459779;PMC8124430;34269011;PMC5733604;PMC10303021;PMC10803515;PMC8120916;PMC9977801;PMC6468798;PMC10060640;35637975;PMC5985397;PMC8387184;PMC7113201;PMC9862468;PMC9180404;PMC8045357;31910343;33717088;PMC7281985;PMC9957441;29949145;PMC6255943;PMC9863068;35885930;33869908;PMC3169510;PMC3033424;PMC4337831;PMC5053416;37439172;PMC7137306;PMC10092772;PMC9387810;PMC6852915;PMC9219990;PMC4567271;PMC7033935;PMC5103287;PMC7179228;PMC4060367;PMC6527596;PMC9937765;PMC9131122;PMC6893029;PMC9320261;PMC9100906;PMC4557053;PMC4481308;PMC9503477;PMC3876085;PMC4147158;PMC6039462;PMC5029065;PMC9021302;PMC8147237;PMC5296369;PMC10267152;PMC6820353;PMC10743219;PMC7020096;PMC10660696;PMC10428630;PMC9523483;PMC10742005;PMC9776935;PMC6912432;PMC5085116;19144316;PMC9072032;PMC7141419;PMC5801414;25548153;PMC9914104;PMC7281609;PMC8117219;PMC10183574;PMC5845882;PMC4962986;PMC9264817;PMC5686097;22387553;PMC414266 ...
# (45003, 'miR-34a', 'TP53', 'MIR_GENE;NEU', 'hsa', 'PMC6977468;PMC6929124;PMC3434411;PMC3229974;23036084;PMC6336680;PMC9190692;PMC4495428;PMC9408007;PMC6271734;PMC5203917;PMC5660088;PMC3497334;35330685;PMC5973863;PMC4637210;PMC8392367;PMC7408939;PMC4981319;PMC6478121;PMC5772851;PMC10584721;PMC5073231;PMC7140674;PMC3160337;PMC7072660;PMC7139490;PMC3358265;21217645;PMC9357370;PMC6031650;PMC10217757;PMC3606220;PMC4122974;PMC6134555;PMC6468660;18677110;30858134;PMC3229581;PMC5058779;PMC9956318;33718673;23416168;26341473;24739178;PMC5374322;PMC6816564;PMC3448677;PMC9181073;PMC3821651;PMC10791979;PMC4810115;PMC10164299;PMC5462749;24642471;25217526;PMC3311059;PMC6360685;PMC5242015;PMC7279373;PMC4139809;PMC7288956;PMC6463186;PMC3912349;PMC9002436;PMC5386646;PMC10164962;19921694;PMC4739602;PMC5187803;PMC5081972;25771001;PMC7645065;PMC5352406;PMC4225545;PMC3157715;PMC10561733;21448283;PMC6826455;PMC5355094;PMC5355306;19736307;PMC8065760;PMC7045593;PMC4336680;PMC5466768;PMC4260944;PMC5748672;PMC8378762;30387834;PMC10251868;PMC7305227;PMC7459507;PMC5426004;PMC2841584;PMC5320387;PMC5297851;PMC3406012;PMC7504607;PMC2705852;PMC10621324;PMC4417562;PMC7140102;PMC5937771;PMC6816179;PMC8008071;PMC4503669;PMC10487838;30944658;PMC7159166;21702042;PMC4477216;PMC7072921;PMC3047136;PMC7086370;21690328;PMC4477183;PMC5083978;PMC7248367;PMC6421700;PMC5666771;PMC9504570;PMC3525943;25362853;PMC3037971;35264576;PMC10110844;PMC9817684;PMC3070685;PMC6928910;PMC3828615;PMC6325163;PMC2952964;23292869;PMC7347005;PMC9319211;PMC5659022;PMC4597437;PMC5632457;PMC8101138;PMC3094321;PMC2892453;PMC10460053;PMC3554575;20598588;PMC3845018;PMC9495382;PMC4462886;PMC9406349;PMC3813786;PMC4555078;PMC4246619;PMC10388388;PMC4237825;PMC9978489;PMC4859802;PMC5805260;PMC3213160;PMC7016744;PMC6723080;PMC4039115;PMC4741184;PMC4772015;PMC5400590;PMC5410295;PMC2690402;PMC5226533;PMC5596565;PMC3563491;PMC10138995;PMC3821583;22623155;PMC3713000;PMC8431668;PMC3509128;PMC10372646;PMC3213093;PMC6032387;PMC7490273;PMC5601167;PMC5322748;PMC4451970;PMC4754861;PMC6470498;PMC7528083;PMC9254375;PMC9149963;PMC6963792;PMC5509453;PMC6829508;PMC6479553;PMC8446062;PMC9026478;PMC4341845;PMC8268032;31532130;PMC4091869;PMC2956090;PMC6885777;PMC9318640;PMC7084905;22020437;31425738;PMC7566714;PMC9950242;PMC8150298;PMC5122370;PMC4177398;PMC4203685;PMC9735783;PMC10499539;PMC10607732;PMC7246662;19221490;PMC4289375;PMC3372529;PMC4054680;31244419;PMC3790106;PMC4936740;PMC4862407;PMC3943297;PMC4414168;17540598;21182263;PMC5442347;22198213;PMC10297163;PMC4963207;21622730;PMC5474465;PMC3498227;26523671;PMC4065722;PMC6206098;30362332;24457968;PMC3256223;PMC10317834;PMC9099786;PMC4496365;18633110;PMC4404052;PMC10824707;PMC3615155;PMC4180389;PMC9626984;PMC4867976;PMC6754866;PMC3427493;PMC5514220;PMC7366700;PMC3794731;PMC5270669;26691544;PMC3153928;24401748;PMC6048189;37467842;PMC4872728;17554199;PMC3561246;PMC7049454;23796712;22610076;PMC6202666;PMC3824539;PMC9199308;PMC6275070;21297663;PMC8394868;PMC3091750;34655330;PMC4333765;PMC3338094;PMC7050126;PMC3120860;PMC4846847;36683916;PMC10453581;PMC2887798;PMC5709393;PMC9714065;25971364;PMC5758781;PMC4381575;PMC4057237;PMC6406044;PMC10093070;PMC3936808;PMC2716485;PMC5687630;PMC3040173;PMC4311467;24232982;PMC7519443;PMC6757293;PMC9954576;20470934;PMC5945834;PMC9953219;30899304;PMC8087466;19373781;24185900;PMC4381606;PMC3775316;PMC9497236;30210668;20089965;PMC5187829;PMC6312226;PMC3250472;36831485;PMC9266862;PMC4547013;19696787;PMC10296342;PMC3931274;PMC7041753;PMC6717636;PMC5682661;38045265;PMC4959878;22531959;22237142;PMC2744658;PMC3171461;PMC5605522;PMC6164944;25896587;PMC8389562;PMC3464169;22301190;PMC10458232;PMC6129576;PMC10419063;PMC2815728;PMC9593298;PMC9564103;PMC3956911;PMC6030072;18941118;PMC8411701;PMC7018700;PMC8149618;PMC6457051;PMC4764688;PMC3941938;PMC5286431;PMC10417274;PMC6747266;29128636;PMC3289600;30512967;PMC9720152;PMC6121310;PMC7338567;PMC6321452;PMC6319339;PMC5095347;24922076;PMC9502703;PMC3899709;PMC5674931;PMC10377597;26734641;PMC6562863;PMC8231 ...
# (35737, 'miR-17', 'MIR17HG', 'MIR_GENE;NEU', 'hsa;mmu', 'PMC9780260;PMC9039675;PMC6468559;PMC6271734;PMC4008308;PMC5075644;32729291;PMC8001136;PMC5855682;PMC7582560;PMC9480495;PMC4875694;33787364;PMC3024412;PMC4464030;PMC3431339;PMC3466182;PMC6548759;32884453;PMC3048474;PMC9031307;26837962;PMC8487119;PMC8326232;PMC7649074;35116852;30972482;PMC8125123;PMC6731105;PMC5374322;PMC4998608;PMC3266933;PMC6042241;PMC6947029;PMC5492016;PMC6165870;PMC3821651;PMC6180493;PMC5665905;PMC8465124;PMC4373247;PMC9719157;PMC7478248;PMC2836279;PMC3266266;PMC4848958;PMC5239490;PMC9944299;PMC5050216;PMC6530353;PMC4658114;PMC4743484;PMC4163377;PMC3777996;PMC3048316;PMC9179866;PMC7447641;24598644;PMC6702344;31578932;PMC6928177;PMC2874222;PMC7646292;PMC6447709;22095742;PMC6387366;PMC7423804;PMC5362961;PMC6311029;19390056;PMC6912346;PMC5979613;PMC4394731;PMC3497323;PMC7081195;PMC10309992;PMC9658179;25597017;PMC5368693;30668139;PMC6308141;33096318;PMC5948221;PMC10625951;PMC4561802;PMC5994557;PMC5932537;PMC6995162;PMC5385369;PMC5652785;PMC3723828;PMC6947031;PMC4978424;PMC3017054;PMC8452045;PMC6196003;27630293;PMC4329769;PMC4499379;PMC8431637;PMC10296502;PMC6332539;PMC9396353;PMC6697918;PMC4864538;PMC9181530;PMC6566171;PMC4637292;PMC4757586;PMC5542167;22731656;31160087;PMC7069088;PMC5681773;17384677;PMC5864932;PMC3794782;PMC3914893;PMC7419621;PMC10298439;PMC4891277;30275704;PMC6863924;PMC6468614;PMC5412469;PMC5030476;23575307;PMC9551393;PMC5349869;PMC5642632;PMC3743212;PMC3497032;28560387;PMC5378724;PMC7008726;23602254;PMC4284676;PMC4068038;PMC2098778;PMC5642528;PMC9740066;PMC3583137;PMC6011049;PMC4807984;PMC3154569;PMC2254598;PMC7547657;PMC3194799;22308110;PMC5024426;PMC6775665;PMC8058364;PMC4441154;PMC3527455;PMC9313100;PMC7016744;PMC4130027;28697830;PMC10073704;PMC10641059;PMC3633049;PMC7378053;PMC4770416;35767105;PMC10770062;PMC4561886;35137671;PMC4636184;PMC4781929;PMC7456828;PMC7078346;31146974;PMC9322918;PMC8272270;PMC9849909;PMC5696470;PMC4340958;PMC8261093;PMC4015287;PMC7473303;33293632;PMC6560107;PMC5506009;PMC3463915;PMC4517134;PMC5967698;PMC8166991;PMC6959019;PMC5078094;PMC6134714;24645838;PMC10455277;PMC8005118;PMC6405743;PMC4421800;PMC6447777;28232590;PMC6868026;28987387;26472816;PMC7104535;35681567;PMC5428505;PMC4151544;PMC6766139;PMC5355239;PMC4604099;PMC4030135;PMC3485010;PMC4695126;PMC3709785;PMC9522259;PMC5067373;29143996;PMC9953941;PMC6372475;PMC6180506;PMC4036714;24681164;PMC4562375;25047501;PMC9844450;PMC7084923;PMC7640435;PMC3692530;PMC5314118;PMC8269043;PMC5630368;PMC3796314;PMC5979519;25680407;PMC2777939;PMC5504285;PMC6269661;PMC3564712;PMC5466994;32255245;PMC6768098;PMC3443098;21806958;PMC6698482;PMC6429746;PMC4180389;PMC7139820;PMC5893605;PMC9656972;PMC5259667;PMC7139390;PMC3565335;PMC8257715;PMC3794731;PMC7457078;PMC4077061;PMC10296542;PMC4224453;PMC5047671;PMC3827895;PMC6721826;PMC7555640;PMC3685817;20133587;PMC2435600;PMC9470859;PMC6378081;PMC5884522;PMC5053622;PMC5707063;PMC5567103;PMC3434024;PMC4662471;PMC8158355;PMC8035363;28222938;PMC3983236;20008935;PMC2644714;27531611;26868909;PMC4377470;PMC6549003;20299512;PMC5340125;PMC5784706;PMC6896016;PMC10421706;PMC6700302;PMC3360479;PMC8001288;PMC8156729;25732734;PMC4381575;PMC5312925;35016493;PMC9355085;PMC9209371;19933089;PMC6104013;PMC4620719;26998831;PMC8138323;PMC5996577;PMC6963872;PMC7073265;16266980;PMC6068727;23258273;PMC6271640;PMC8430640;32233464;PMC3759866;PMC5522042;PMC4834410;PMC4605595;PMC4108130;PMC7505278;27577994;18941111;26804174;PMC5597599;PMC5687634;PMC3116840;PMC4810107;PMC8379081;PMC5760013;PMC10219488;PMC4677400;PMC2718498;PMC3527550;PMC4657041;PMC4667639;PMC10296615;PMC3583619;PMC5979355;26276869;PMC8156480;PMC4579969;PMC5359838;PMC4803811;PMC5796233;PMC9593298;PMC10419063;PMC7521527;PMC2978113;PMC2907339;PMC6230569;PMC5870037;PMC3112430;PMC9068604;PMC5982768;PMC3522018;31029648;PMC9745093;PMC10571949;PMC5689669;23551855;29530952;35328059;PMC5797348;22267003;PMC5979329;PMC2797535;PMC2945769;37371832;PMC3296594;PMC8064455;PMC4019893;PMC6989481;PMC10371352;PM ...
# (35738, 'miR-17', 'MIR17HG', 'GENE_MIR;NEU', 'hsa;mmu', 'PMC4150436;PMC3996893;PMC6271734;PMC6338066;PMC8001136;PMC8307416;PMC7582560;PMC4875694;PMC4142865;PMC3431339;PMC6036139;PMC3466182;32884453;PMC3070678;PMC9031307;PMC7246719;PMC5460214;PMC3539910;29902577;PMC2780389;PMC3544584;PMC8487119;PMC7649074;35116852;PMC4186561;PMC4602285;30972482;PMC6731105;PMC4998608;PMC6609535;PMC5932548;PMC3266933;PMC5492016;PMC6038585;PMC6180493;PMC4581219;PMC5051645;PMC9719157;PMC2836279;PMC5222723;21220470;PMC5239490;PMC9944299;PMC5050216;24076654;PMC3808701;PMC6530353;PMC4658114;PMC7302353;PMC3884629;PMC3777996;PMC7589124;PMC3876682;PMC6702344;31578932;PMC2874222;PMC6691717;17586726;PMC3718810;PMC6447709;22095742;PMC8002857;PMC2678255;PMC7645065;PMC5362961;PMC7320137;PMC3796390;PMC8024481;PMC5355306;PMC6522715;PMC8391635;PMC6912833;33096318;PMC5948221;PMC10625951;PMC4561802;28420612;PMC5652785;PMC6693234;PMC6947031;PMC6196003;30443163;PMC4499379;PMC3806224;PMC8431637;29149826;PMC2674802;PMC2967070;PMC10296502;PMC6088237;PMC4637292;PMC4757586;PMC10537407;PMC5542167;PMC7016591;PMC9208480;36523768;PMC7069088;PMC8460875;PMC3794782;PMC9219780;28187958;25881561;PMC4891277;37366574;PMC5030476;26117336;PMC9779565;PMC4632748;PMC5642632;PMC6013767;PMC3821599;PMC4284676;PMC8460807;PMC5400662;PMC2669448;PMC7547657;PMC3194799;PMC4351951;PMC7561394;PMC9104095;PMC9008777;22308110;PMC6540078;PMC6410298;PMC5024426;PMC9138876;PMC6775665;PMC8058364;PMC5741618;PMC3527455;PMC7016744;PMC4130027;PMC8345394;PMC3212852;PMC10073704;PMC3044711;PMC3859655;PMC9958963;PMC4171621;PMC10641059;PMC8308570;PMC3224893;PMC10770062;PMC4561886;PMC4636184;28810605;33293478;PMC7349855;PMC8272270;PMC10707120;PMC5696470;PMC4340958;PMC8261093;PMC4015287;PMC5506009;PMC6560107;PMC3950692;PMC3463915;PMC5967698;PMC8125142;PMC2490676;PMC5078094;PMC6134714;PMC3934005;PMC4421800;PMC6447777;PMC10625245;PMC5191871;PMC5855821;PMC8243427;37984445;PMC3102725;26472816;PMC7104535;PMC3203863;PMC5428505;PMC10499539;PMC4151544;27568466;PMC5355239;PMC3267163;PMC3485010;PMC3709785;PMC5067373;29143996;PMC7053084;PMC6180506;PMC4505342;PMC9503263;PMC6348679;PMC4170827;PMC4452061;PMC10093969;PMC7640435;PMC6678568;PMC3692530;PMC5238428;PMC5314118;PMC5630368;PMC10027640;32606766;PMC3796314;PMC10531155;PMC4405876;PMC5504285;PMC10460564;PMC4350361;PMC3443098;24360091;PMC9624419;PMC8068787;PMC4308918;PMC6429746;PMC4180389;PMC5893605;PMC4278269;PMC5259667;PMC6038278;PMC3008681;PMC7457078;PMC3794731;PMC3252342;PMC4224453;PMC5047671;PMC3827895;PMC10008945;PMC6378081;PMC5884522;PMC4446110;PMC5053622;PMC5707063;PMC5567103;PMC2848978;32466856;PMC5192506;PMC5359825;PMC4662471;PMC4925891;28222938;PMC3983236;20008935;PMC2644714;26868909;PMC4377470;PMC6549003;21972292;PMC6700302;PMC5960494;PMC6329178;PMC8001288;24462553;PMC5027393;PMC4381575;24969314;PMC4005632;PMC3217971;PMC4445322;PMC8138323;PMC6969641;PMC5996577;16266980;PMC6068727;PMC6769579;PMC8430640;PMC3759866;PMC5522042;PMC4834410;PMC10501107;PMC4605595;23532756;PMC5354650;35797991;PMC3566108;PMC5597599;18941111;PMC5687634;PMC3250472;PMC3120759;PMC10017462;PMC3116840;PMC7084225;PMC4810107;PMC6221902;PMC10219488;PMC2718498;PMC9564236;PMC3527550;PMC4657041;PMC5363537;PMC10296615;26276869;PMC8156480;PMC5796233;PMC10419063;PMC7521527;PMC2978113;PMC6230569;PMC9777028;PMC5870037;PMC5982768;PMC9745093;PMC4876347;PMC10571949;PMC3356405;PMC5797348;33622246;20406979;PMC2797535;PMC4689037;PMC9139326;PMC10134903;PMC8064455;PMC4019893;PMC6989481;PMC10067680;PMC10371352;PMC4519968;PMC5669908;PMC5642611;PMC8147187;PMC4730335;PMC4018277;PMC6954528;PMC4008267;PMC4294389;PMC7531112;PMC5877740;PMC3000827;30873941;PMC3843544;PMC4853423;PMC5532254;PMC7266940;PMC8017203;PMC5355440;PMC2777376;PMC4072627;PMC4032243;PMC8272376;PMC6953218;PMC10661689;PMC5173166;PMC6794783;PMC10528641;PMC6556968;PMC7445987;PMC9779654;PMC6406430;PMC4581079;PMC7547478;PMC3877075;PMC4882787;PMC2254191;24285176;PMC4494690;PMC8394585;PMC4751888;PMC4008358;PMC2736819;PMC2984457;PMC5002215;PMC3102634;PMC3482395; ...

# %%
con.close()

# %%
con =  sqlite3.connect(dbFile)
cur = con.cursor()

# %%
a = cur.execute("SELECT * FROM mx where gene_family='MYC' and mirna_family='let-7a'")
for x in a:
    print(x)
# Out:
# (155177, 'let-7a', 'MYC', 'MIR_GENE;DOWN', 'hsa;mmu', 'PMC2133370;23676502;PMC5862327;PMC8155106;PMC3563491;PMC10130400;PMC6805781;PMC5683570;PMC4578885;30531691;PMC9179868;PMC7449869;PMC4536995;PMC5302913;PMC5302924;17942906;PMC10228081;PMC9562880;PMC5685744;PMC7369991;28494471;PMC9440497;PMC3382602;PMC4188135;PMC5269535;PMC3634476;PMC4742387;PMC5500619;PMC5209603;PMC5607853;21903590;20033209;PMC6796902;PMC3874662;PMC4385600;PMC10455604;PMC5979478;25077964;PMC10295928;PMC5005617;PMC10537407;PMC8417529;PMC4547013;PMC5289991;PMC7016591', "('PMC10295928.3.35', (13, 19), (97, 102));('PMC10228081.3.319', (116, 122), (126, 129));('PMC5685744.3.144', (82, 88), (109, 112));('PMC10228081.3.159', (153, 159), (174, 177));('PMC9179868.3.107', (156, 163), (51, 56));('PMC5685744.3.119', (143, 150), (78, 81));('17942906.2.11', (70, 76), (19, 22));('PMC7449869.3.43', (101, 107), (47, 50));('PMC5685744.3.146', (57, 63), (128, 131));('PMC10537407.3.126', (113, 121), (14, 17));('PMC5500619.3.50', (6, 12), (28, 31));('20033209.1.1', (4, 10), (87, 92));('PMC7449869.3.38', (64, 79), (110, 113));('PMC5862327.3.212', (138, 143), (170, 173));('PMC5302913.2.4', (151, 157), (89, 92));('PMC5005617.3.165', (197, 203), (129, 134));('PMC7016591.3.57', (150, 156), (40, 45));('PMC5302913.3.72', (81, 87), (34, 37));('PMC6805781.3.118', (46, 51), (11, 14));('PMC4578885.2.10', (84, 90), (50, 55));('21903590.2.6', (30, 36), (13, 16));('PMC5302924.3.75', (32, 38), (97, 102));('PMC10130400.3.248', (30, 36), (70, 73));('PMC5302913.3.13', (325, 331), (270, 273));('PMC3874662.3.53', (85, 91), (0, 3));('PMC5209603.3.140', (0, 6), (83, 88));('PMC3563491.3.135', (34, 40), (148, 153));('PMC4578885.3.204', (216, 222), (24, 29));('PMC4536995.3.85', (52, 58), (29, 34));('PMC4578885.3.189', (128, 134), (78, 83));('PMC9440497.3.157', (66, 73), (31, 34));('30531691.2.9', (40, 46), (110, 115));('25077964.2.6', (30, 36), (177, 180));('PMC6796902.3.81', (127, 134), (13, 16));('PMC10455604.3.75', (34, 44), (126, 131));('PMC5685744.3.143', (24, 30), (60, 63));('PMC6796902.3.79', (113, 119), (49, 52));('PMC3634476.3.35', (0, 6), (60, 63));('PMC10130400.3.264', (0, 6), (62, 67));('PMC4188135.3.64', (85, 91), (197, 202));('PMC4547013.3.28', (201, 207), (267, 270));('PMC4385600.3.106', (103, 111), (29, 34));('PMC4578885.3.193', (83, 89), (35, 40));('PMC10228081.3.266', (32, 38), (146, 149));('17942906.2.10', (18, 25), (42, 45));('28494471.2.16', (13, 22), (91, 96));('PMC9562880.3.83', (17, 23), (45, 50));('PMC8155106.3.99', (4, 10), (149, 154));('20033209.2.12', (18, 24), (132, 137));('PMC3382602.3.18', (36, 42), (70, 73));('PMC5269535.3.91', (43, 49), (114, 117));('PMC6796902.3.80', (94, 100), (22, 25));('PMC4742387.3.77', (14, 20), (103, 106));('17942906.1.1', (9, 15), (31, 34));('PMC5979478.3.125', (27, 33), (104, 107));('PMC5302913.3.14', (132, 138), (82, 85));('PMC5302913.3.106', (38, 44), (102, 105));('PMC5683570.3.167', (40, 46), (275, 278));('PMC7449869.3.38', (211, 217), (315, 318));('PMC4536995.3.87', (178, 184), (280, 285));('PMC4578885.3.180', (256, 262), (164, 169));('PMC5607853.3.76', (6, 12), (46, 51));('PMC10228081.3.319', (70, 76), (126, 129));('PMC7369991.3.61', (248, 257), (447, 450));('PMC2133370.3.130', (38, 44), (157, 162));('PMC3634476.3.38', (146, 152), (33, 36));('23676502.2.8', (85, 91), (146, 149));('PMC7449869.3.44', (64, 70), (57, 60));('PMC4536995.3.111', (0, 6), (34, 39));('PMC8417529.3.87', (242, 248), (205, 210));('PMC5289991.3.174', (130, 138), (15, 18));('PMC9440497.3.156', (71, 77), (105, 108));('PMC7449869.3.53', (163, 178), (179, 182));('PMC2133370.3.124', (0, 6), (93, 98))", 45, 74, 0)
# (155178, 'let-7a', 'MYC', 'GENE_MIR;UP', 'hsa;mmu', 'PMC5302913;17942906;21903590;31298382;PMC9687916;PMC6331425;PMC4868734;PMC4926514', "('31298382.2.4', (55, 60), (228, 234));('PMC5302913.3.44', (158, 161), (354, 360));('PMC5302913.3.104', (36, 41), (129, 135));('PMC6331425.3.165', (25, 28), (81, 87));('21903590.2.9', (63, 66), (110, 116));('PMC5302913.3.102', (268, 273), (363, 369));('PMC4926514.3.79', (51, 56), (84, 90));('17942906.2.11', (52, 55), (70, 76));('21903590.2.9', (68, 71), (110, 116));('PMC4868734.3.49', (26, 31), (128, 134));('PMC9687916.3.126', (0, 3), (28, 34))", 8, 11, 0)
# (155179, 'let-7a', 'MYC', 'MIR_GENE;UP', 'hsa;mmu', 'PMC5302913;PMC7645065;37254190;17942906;PMC10228081;33206791;PMC9074781;PMC8082653;PMC9440497;27593875;PMC5663521', "('17942906.2.15', (20, 26), (52, 55));('PMC7645065.3.258', (124, 130), (168, 173));('PMC5302913.3.43', (114, 120), (29, 32));('PMC10228081.2.5', (159, 165), (178, 181));('37254190.2.5', (159, 165), (178, 181));('PMC8082653.3.124', (57, 63), (40, 43));('PMC9074781.3.133', (44, 53), (115, 118));('33206791.2.9', (25, 31), (123, 128));('PMC5663521.3.148', (157, 163), (199, 202));('27593875.2.5', (37, 43), (79, 84));('PMC9440497.3.152', (112, 118), (78, 81))", 11, 11, 0)
# (155180, 'let-7a', 'MYC', 'GENE_MIR;NEU', 'hsa;mmu', 'PMC3213110;21903590;PMC4617986;PMC6331425;PMC4578885;PMC4983322;PMC5302913;PMC7645065;17942906;PMC10228081;PMC7352788;31298382;28494471;PMC4188135;PMC5269535;PMC3634476;PMC4742387;PMC8227213;PMC4868734;PMC5607853;PMC8391329;PMC4446438', "('28494471.2.16', (91, 96), (135, 144));('PMC4446438.3.133', (49, 52), (156, 162));('PMC7645065.3.145', (139, 144), (111, 117));('PMC4578885.3.190', (23, 28), (55, 61));('PMC5302913.3.99', (17, 20), (86, 92));('PMC4617986.3.135', (44, 49), (160, 166));('PMC4868734.3.59', (212, 217), (294, 301));('PMC5302913.3.101', (63, 66), (138, 144));('PMC5607853.3.84', (101, 106), (201, 207));('PMC5302913.2.7', (61, 64), (135, 141));('PMC8391329.3.39', (125, 130), (0, 6));('PMC5302913.3.73', (84, 87), (94, 100));('PMC5302913.3.102', (65, 68), (212, 218));('PMC10228081.3.259', (14, 17), (110, 116));('21903590.2.10', (41, 44), (118, 124));('PMC4578885.2.4', (115, 120), (15, 21));('PMC8227213.3.90', (32, 35), (80, 88));('PMC4983322.3.177', (24, 27), (71, 77));('PMC4578885.2.4', (62, 67), (167, 173));('PMC5302913.3.62', (117, 120), (170, 176));('PMC5302913.3.101', (48, 51), (138, 144));('PMC4742387.3.80', (15, 18), (77, 83));('PMC4868734.3.60', (36, 41), (69, 75));('PMC4188135.3.71', (57, 62), (28, 34));('PMC4578885.2.4', (220, 225), (15, 21));('17942906.2.12', (104, 107), (33, 39));('31298382.2.4', (277, 282), (228, 234));('PMC7352788.3.120', (129, 132), (12, 17));('PMC7352788.3.120', (38, 41), (12, 17));('21903590.2.10', (56, 59), (118, 124));('PMC5269535.3.90', (106, 109), (134, 140));('PMC6331425.3.155', (31, 34), (85, 91));('PMC4578885.3.202', (25, 30), (64, 70));('PMC3634476.3.38', (33, 36), (266, 271));('PMC5302913.3.103', (10, 15), (77, 83));('PMC3213110.3.128', (164, 167), (333, 345));('PMC4578885.3.112', (127, 132), (154, 160))", 22, 37, 0)
# (155181, 'let-7a', 'MYC', 'MIR_GENE;NEU', 'hsa;mmu', '30515781;PMC10059597;PMC4578885;PMC7449869;PMC4536995;PMC3065009;PMC9849253;PMC5302924;PMC3527265;PMC6123370;27593875;PMC6712829;PMC2098778;PMC5607853;33162208;PMC6515063;PMC4385600;PMC8064455;PMC4180389;PMC4581219;PMC5539934;PMC3496131;PMC5796693;PMC8486517;PMC4168040;PMC3656880;PMC4868734;23676502;PMC8344971;PMC3563491;PMC9967195;PMC2974699;PMC5683570;PMC4609421;PMC4051699;PMC3154507;PMC7645065;17942906;PMC10228081;PMC5386684;PMC6049865;PMC9440497;PMC4188135;PMC5343810;PMC5269535;PMC6912346;PMC4695033;PMC9820223;PMC3213110;PMC4617986;PMC7225988;PMC9028641;PMC6796902;PMC6460386;PMC4730277;PMC6576772;PMC7226055;PMC4079640;31298382;PMC3200989', "('PMC8344971.3.40', (4, 10), (131, 134));('PMC4695033.3.228', (10, 16), (337, 340));('PMC4536995.3.91', (99, 105), (29, 32));('PMC4180389.3.64', (28, 34), (168, 171));('23676502.2.3', (18, 24), (73, 78));('PMC5539934.3.114', (59, 66), (152, 157));('PMC7449869.3.38', (150, 156), (110, 113));('PMC4079640.3.112', (25, 31), (105, 110));('PMC4536995.3.83', (25, 31), (208, 213));('PMC4536995.3.82', (166, 173), (135, 140));('PMC5386684.3.65', (331, 337), (369, 374));('PMC8486517.3.200', (13, 19), (195, 200));('PMC4188135.3.68', (14, 20), (117, 122));('PMC3200989.3.51', (90, 96), (60, 65));('31298382.1.1', (39, 45), (150, 155));('PMC6576772.3.118', (64, 70), (84, 87));('PMC3527265.3.72', (28, 34), (106, 109));('PMC3496131.3.101', (47, 53), (91, 96));('PMC4536995.2.6', (46, 52), (81, 86));('PMC3656880.3.147', (39, 45), (93, 96));('PMC7645065.3.258', (34, 40), (49, 54));('PMC10228081.3.269', (53, 59), (34, 37));('PMC4581219.3.43', (40, 46), (123, 126));('PMC5343810.3.86', (14, 21), (105, 108));('PMC4168040.3.146', (226, 233), (95, 100));('PMC6123370.3.178', (35, 41), (113, 118));('PMC5607853.3.12', (31, 37), (48, 53));('PMC5302924.3.127', (174, 180), (91, 96));('PMC4168040.3.146', (80, 86), (95, 100));('PMC9440497.3.152', (112, 118), (174, 177));('PMC9028641.3.117', (94, 100), (256, 259));('PMC4536995.3.199', (117, 123), (96, 101));('PMC4188135.3.62', (0, 6), (56, 61));('PMC6712829.3.23', (163, 169), (191, 196));('PMC4385600.3.106', (103, 111), (251, 256));('PMC5607853.3.84', (201, 207), (218, 223));('PMC3213110.3.128', (333, 345), (287, 290));('PMC7226055.3.123', (391, 397), (133, 136));('PMC10228081.3.265', (125, 131), (68, 71));('PMC4079640.3.47', (98, 105), (52, 57));('PMC5539934.3.80', (33, 39), (0, 5));('17942906.2.9', (26, 32), (14, 17));('PMC4578885.2.11', (105, 111), (61, 66));('PMC6515063.3.304', (68, 74), (43, 46));('PMC2098778.3.80', (162, 170), (45, 50));('PMC5539934.3.80', (174, 180), (0, 5));('PMC5269535.3.92', (56, 62), (107, 110));('PMC6049865.3.10', (93, 99), (225, 228));('PMC4868734.3.17', (26, 32), (92, 97));('30515781.2.8', (177, 186), (24, 27));('PMC7449869.3.78', (33, 39), (129, 132));('PMC4051699.3.182', (64, 70), (110, 113));('PMC4578885.3.17', (197, 203), (133, 138));('PMC6912346.3.14', (234, 241), (171, 174));('PMC7225988.3.109', (172, 178), (221, 226));('31298382.2.4', (288, 294), (55, 60));('PMC3154507.3.199', (0, 6), (93, 96));('PMC9820223.3.106', (174, 183), (123, 126));('PMC6460386.3.151', (92, 99), (43, 48));('PMC5683570.3.109', (70, 79), (178, 181));('PMC9849253.3.126', (41, 47), (59, 64));('PMC2974699.3.105', (52, 58), (22, 25));('PMC10228081.3.259', (93, 99), (14, 17));('PMC4617986.3.128', (190, 196), (150, 155));('PMC3496131.3.86', (170, 176), (230, 235));('PMC4536995.3.87', (14, 20), (73, 78));('PMC5269535.3.90', (47, 53), (106, 109));('PMC8064455.3.333', (0, 9), (136, 139));('PMC4609421.3.142', (28, 34), (106, 109));('PMC3065009.3.82', (32, 38), (56, 61));('PMC5796693.3.225', (0, 6), (17, 20));('PMC4536995.3.86', (57, 63), (25, 30));('PMC4536995.3.132', (149, 155), (117, 122));('PMC9967195.3.180', (4, 10), (38, 43));('PMC5269535.3.120', (35, 41), (96, 99));('PMC3563491.3.134', (181, 187), (169, 172));('33162208.2.10', (65, 71), (216, 221));('PMC3496131.3.94', (53, 59), (89, 94));('27593875.2.4', (169, 175 ...
# (155182, 'let-7a', 'MYC', 'GENE_MIR;DOWN', 'hsa;mmu', 'PMC5302913;PMC7645065;21903590;PMC4932749;31298382;PMC6460386;PMC3934005;PMC6331425;PMC4188135;PMC5269535;PMC4578885;PMC7449869;PMC9369058', "('PMC5302913.2.1', (29, 32), (90, 96));('PMC5302913.3.98', (167, 170), (205, 211));('PMC5302913.2.8', (191, 194), (303, 309));('PMC4578885.1.1', (0, 5), (45, 51));('PMC7449869.3.42', (32, 35), (66, 72));('PMC7645065.3.258', (23, 28), (0, 6));('31298382.2.5', (146, 151), (0, 6));('PMC5302913.3.63', (282, 285), (322, 328));('31298382.2.5', (178, 183), (0, 6));('PMC5302913.3.17', (90, 93), (136, 142));('PMC3934005.3.172', (59, 64), (161, 167));('PMC5302913.3.64', (25, 30), (62, 68));('PMC4188135.3.78', (88, 93), (215, 221));('PMC7449869.3.50', (103, 106), (137, 144));('PMC5269535.2.9', (40, 43), (81, 87));('PMC5302913.3.63', (34, 37), (70, 76));('PMC4932749.3.252', (136, 141), (172, 178));('PMC5302913.3.9', (37, 40), (53, 59));('PMC6331425.3.157', (97, 100), (199, 205));('21903590.1.1', (0, 3), (62, 68));('PMC4578885.3.207', (109, 114), (65, 71));('PMC6460386.3.152', (21, 26), (109, 115));('PMC9369058.3.78', (71, 76), (22, 28));('PMC4578885.3.209', (0, 5), (41, 47));('PMC5302913.1.1', (8, 11), (109, 115));('PMC5302913.3.62', (0, 3), (49, 55))", 13, 26, 0)

# %%
#Total Document with miRNA-gene interaction

a = cur.execute("SELECT count( distinct doc_id) FROM mx_sent")
for x in a:
    print(x)
# Out:
# (102611,)

# %%
# Number of different genes
a = cur.execute("SELECT count( distinct gene_family) FROM mx")
for x in a:
    print(x)
    
#Number of different miRNAs (precursor level)
a = cur.execute("SELECT count( distinct mirna_family) FROM mx")
for x in a:
    print(x)
# Out:
# (14113,)
# (2018,)

# %%
a = cur.execute("SELECT interaction, count(interaction) FROM mx WHERE is_consensus = 1 GROUP BY interaction;")
for x in a:
    print(x)
# Out:
# ('GENE_MIR;DOWN', 9320)
# ('GENE_MIR;NEU', 43767)
# ('GENE_MIR;UP', 10464)
# ('MIR_GENE;DOWN', 53161)
# ('MIR_GENE;NEU', 117698)
# ('MIR_GENE;UP', 25294)

# %%
a = cur.execute("SELECT count(distinct concat_ws(' ', gene_family, mirna_family)) FROM mx WHERE is_consensus = 1;")
for x in a:
    print(x)
# Out:
# (196438,)

# %%
def get_relation_data(cursor, mirna, gene, interaction):
    
    interaction_condition = ""
    if not interaction is None:
        interaction_condition = "and interaction = '{}'".format(interaction)
    
    if mirna and gene:
        sqlres = cursor.execute("""
                    SELECT miRNA_family, gene_family, interaction, evidence_documents FROM mx WHERE miRNA_family='{}' and gene_family='{}' {}
                    ORDER BY evidence_count desc;
                    """.format(mirna, gene, interaction_condition)
                    )
    else:
        if mirna:
            query_equal = "miRNA_family='{}'".format(mirna)
        else:
            query_equal = "gene_family='{}'".format(gene)
        
        sqlres = cursor.execute("""
                SELECT miRNA_family, gene_family, interaction, evidence_documents FROM mx WHERE {} {}
                ORDER BY evidence_count desc;
                """.format(query_equal, interaction_condition)
                )
    
    results = []
    for x in sqlres:
        results.append({
            "miRNA_family": x[0],
            "gene_family": x[1],
            "interaction": x[2],
            "evidence_documents": x[3],
        })
    return results

# %%
get_relation_data(cur, "miR-124", "CCL2", "MIR_GENE;NEU")
# Out:
# [{'miRNA_family': 'miR-124',
#   'gene_family': 'CCL2',
#   'interaction': 'MIR_GENE;NEU',
#   'evidence_documents': 'PMC8201518'}]

# %%
def get_annot_data(cursor, documents, rel_annotations=['celllines', 'disease', 'GeneOntology']):
    sqlres = cursor.execute("""
                SELECT doc_id, annotation, concept_id, concept FROM mx_annot WHERE doc_id IN ({}) and annotation IN ({});
                """.format(",".join(["'{}'".format(x) for x in documents]), ",".join(["'{}'".format(x) for x in rel_annotations]))
                )
    
    results = []
    for x in sqlres:
        results.append({
            "doc_id": x[0],
            "annotation": x[1],
            "concept_id": x[2],
            "concept": x[3],
        })
    return results

# %%
annotCounter = Counter([x["concept"] for x in get_annot_data(cur, ['PMC8201518'])])
print(annotCounter.most_common())
# Out:
# [('IgE immunoglobulin complex, circulating', 1), ('sarcoidosis', 1), ('melanoma', 1), ('mesenchymal stem cell', 1), ('primary cutaneous amyloidosis', 1), ('B cell receptor complex', 1), ('bacterial microcompartment', 1), ('immunoglobulin complex, circulating', 1), ('dermatitis', 1), ('MAP kinase activity', 1), ('MAPK cascade', 1), ('mast cell activation', 1), ('lung macrophage', 1), ('obsolete focal adhesion kinase activity', 1), ('lung carcinoma', 1), ('immunoglobulin complex', 1), ('eosinophil', 1), ('cell population proliferation', 1), ('leukemia', 1), ('reactive oxygen species biosynthetic process', 1), ('mast cell', 1), ('cancer', 1), ('carcinoma', 1), ('autophagy', 1), ('developmental process', 1), ('pore complex', 1), ('allergic asthma', 1), ('nascent polypeptide-associated complex', 1), ('angiogenesis', 1), ('miRNA processing', 1), ('biosynthetic process', 1), ('B cell', 1), ('threonine-type endopeptidase activity', 1), ('extracellular exosome', 1), ('asthma', 1), ('hexosaminidase activity', 1), ('obsolete calcium-dependent cell adhesion molecule activity', 1), ('cell activation', 1), ('macroautophagy', 1), ('mast cell proliferation', 1), ('mast cell degranulation', 1), ('obsolete vimentin', 1), ('obsolete tumor suppressor', 1), ('mast cell progenitor', 1), ('regulation of cell cycle', 1), ('obsolete soluble fraction', 1), ('inflammatory response', 1), ('obsolete anaphylaxis', 1), ('large latent transforming growth factor-beta complex', 1), ('type III intermediate filament', 1), ('stem cell', 1)]

# %%
len(annotCounter)
# Out:
# 51

# %%
get_annot_data(cur, ['PMC8201518'])
# Out:
# [{'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0071743',
#   'concept': 'IgE immunoglobulin complex, circulating'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'disease',
#   'concept_id': 'DOID:11335',
#   'concept': 'sarcoidosis'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'disease',
#   'concept_id': 'DOID:1909',
#   'concept': 'melanoma'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'celllines',
#   'concept_id': 'CL:0000134',
#   'concept': 'mesenchymal stem cell'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'disease',
#   'concept_id': 'DOID:0050639',
#   'concept': 'primary cutaneous amyloidosis'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0019815',
#   'concept': 'B cell receptor complex'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0031469',
#   'concept': 'bacterial microcompartment'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0042571',
#   'concept': 'immunoglobulin complex, circulating'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'disease',
#   'concept_id': 'DOID:2723',
#   'concept': 'dermatitis'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0004707',
#   'concept': 'MAP kinase activity'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0000165',
#   'concept': 'MAPK cascade'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0045576',
#   'concept': 'mast cell activation'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'celllines',
#   'concept_id': 'CL:1001603',
#   'concept': 'lung macrophage'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0004717',
#   'concept': 'obsolete focal adhesion kinase activity'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'disease',
#   'concept_id': 'DOID:3905',
#   'concept': 'lung carcinoma'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0019814',
#   'concept': 'immunoglobulin complex'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'celllines',
#   'concept_id': 'CL:0000771',
#   'concept': 'eosinophil'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0008283',
#   'concept': 'cell population proliferation'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'disease',
#   'concept_id': 'DOID:1240',
#   'concept': 'leukemia'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:1903409',
#   'concept': 'reactive oxygen species biosynthetic process'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'celllines',
#   'concept_id': 'CL:0000097',
#   'concept': 'mast cell'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'disease',
#   'concept_id': 'DOID:162',
#   'concept': 'cancer'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'disease',
#   'concept_id': 'DOID:305',
#   'concept': 'carcinoma'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0006914',
#   'concept': 'autophagy'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0032502',
#   'concept': 'developmental process'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0046930',
#   'concept': 'pore complex'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'disease',
#   'concept_id': 'DOID:9415',
#   'concept': 'allergic asthma'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0005854',
#   'concept': 'nascent polypeptide-associated complex'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0001525',
#   'concept': 'angiogenesis'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0035196',
#   'concept': 'miRNA processing'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0009058',
#   'concept': 'biosynthetic process'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'celllines',
#   'concept_id': 'CL:0000236',
#   'concept': 'B cell'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0004298',
#   'concept': 'threonine-type endopeptidase activity'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0070062',
#   'concept': 'extracellular exosome'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'disease',
#   'concept_id': 'DOID:2841',
#   'concept': 'asthma'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0015929',
#   'concept': 'hexosaminidase activity'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0008014',
#   'concept': 'obsolete calcium-dependent cell adhesion molecule activity'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0001775',
#   'concept': 'cell activation'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0016236',
#   'concept': 'macroautophagy'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0070662',
#   'concept': 'mast cell proliferation'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0043303',
#   'concept': 'mast cell degranulation'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0045099',
#   'concept': 'obsolete vimentin'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0008181',
#   'concept': 'obsolete tumor suppressor'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'celllines',
#   'concept_id': 'CL:0000831',
#   'concept': 'mast cell progenitor'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0051726',
#   'concept': 'regulation of cell cycle'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0005625',
#   'concept': 'obsolete soluble fraction'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0006954',
#   'concept': 'inflammatory response'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0030105',
#   'concept': 'obsolete anaphylaxis'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0038045',
#   'concept': 'large latent transforming growth factor-beta complex'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'GeneOntology',
#   'concept_id': 'GO:0045098',
#   'concept': 'type III intermediate filament'},
#  {'doc_id': 'PMC8201518',
#   'annotation': 'celllines',
#   'concept_id': 'CL:0000034',
#   'concept': 'stem cell'}]

# %%
def sqlite_table_schema(conn, name):
    
    cursor = conn.execute("SELECT * FROM {} LIMIT 1;".format(name))
    sql = cursor.fetchone()
    print(sql)
    cursor.close()
    
    
    cursor = conn.execute("SELECT sql FROM sqlite_master WHERE name=?;", [name])
    sql = cursor.fetchone()[0]
    cursor.close()
    return sql

# %%
for table in ["mx", "mx_int", "mx_annot", "mx_sent", "mx_dates"]:
    print(sqlite_table_schema(con, table))
    print()
# Out:
# (0, 'miR-8485', 'INSR', 'MIR_GENE;NEU', 'hsa;mmu', 'PMC5979287', "('PMC5979287.3.54', (149, 157), (275, 291))", 1, 1, 1)
# CREATE TABLE "mx" (
# "index" INTEGER PRIMARY KEY AUTOINCREMENT,
# "miRNA_family" TEXT,
# "gene_family" TEXT,
# "interaction" TEXT,
# "organisms" TEXT,
# "evidence_documents" TEXT,
# "sent_evidences" TEXT,
# "evidence_count" INTEGER,
# "sent_count" INTEGER,
# "is_consensus" INTEGER
# )
#
# (0, 'miR-8485', 'INSR', 'MIR_GENE;NEU', 'PMC5979287')
# CREATE TABLE "mx_int" (
# "index" INTEGER PRIMARY KEY AUTOINCREMENT,
# "miRNA_family" TEXT,
# "gene_family" TEXT,
# "interaction" TEXT,
# "evidence_documents" TEXT
# )
#
# (0, '15766526', 'GeneOntology', 'GO:0035925', "mRNA 3'-UTR AU-rich region binding", 1, '15766526.2.5,73,84')
# CREATE TABLE "mx_annot" (
# "index" INTEGER PRIMARY KEY AUTOINCREMENT,
# "doc_id" TEXT,
# "annotation" TEXT,
# "concept_id" TEXT,
# "concept" TEXT,
# "num_occurrences" INTEGER,
# "sent_evidences" TEXT
# )
#
# (0, 'PMC10208224', 'PMC10208224.3.109', '(B) Penalty plot of 22 immune cells in the LASSO model, error bars represent standard error.\n')
# CREATE TABLE "mx_sent" (
# "index" INTEGER PRIMARY KEY AUTOINCREMENT,
# "doc_id" TEXT,
# "sent_id" TEXT,
# "sentence" TEXT
# )
#
# (0, '22473090', '2012-04-04')
# CREATE TABLE "mx_dates" (
# "index" INTEGER PRIMARY KEY AUTOINCREMENT,
# "doc_id" TEXT,
# "date" TEXT
# )

# %%
import pandas as pd
db_df = pd.read_sql_query("SELECT * FROM mx", con)
db_df.to_csv('mxplore_table_mx.tsv', index=False, sep="\t")
